# %% [markdown]
# # Особенности стресса у девушек-студенток

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Аннотация" data-toc-modified-id="Аннотация-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Аннотация</a></span></li><li><span><a href="#Первичная-обработка-результатов-анкетирования" data-toc-modified-id="Первичная-обработка-результатов-анкетирования-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Первичная обработка результатов анкетирования</a></span><ul class="toc-item"><li><span><a href="#Социально-психологические-и-медико-социальные-характеристики" data-toc-modified-id="Социально-психологические-и-медико-социальные-характеристики-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Социально-психологические и медико-социальные характеристики</a></span></li><li><span><a href="#Маскулинность,-феминность-и-гендерный-тип-личности" data-toc-modified-id="Маскулинность,-феминность-и-гендерный-тип-личности-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Маскулинность, феминность и гендерный тип личности</a></span></li><li><span><a href="#Краткая-шкала-академической-мотивации" data-toc-modified-id="Краткая-шкала-академической-мотивации-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Краткая шкала академической мотивации</a></span></li><li><span><a href="#Опросник-повседневных-стрессоров" data-toc-modified-id="Опросник-повседневных-стрессоров-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Опросник повседневных стрессоров</a></span></li><li><span><a href="#Шкала-психологического-стресса-(РSМ-25)" data-toc-modified-id="Шкала-психологического-стресса-(РSМ-25)-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Шкала психологического стресса (<em>РSМ-25</em>)</a></span></li><li><span><a href="#Тест-на-стрессоустойчивость" data-toc-modified-id="Тест-на-стрессоустойчивость-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Тест на стрессоустойчивость</a></span></li></ul></li><li><span><a href="#Анализ-корреляционных-связей-изученных-показателей" data-toc-modified-id="Анализ-корреляционных-связей-изученных-показателей-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Анализ корреляционных связей изученных показателей</a></span><ul class="toc-item"><li><span><a href="#Корреляции-признаков" data-toc-modified-id="Корреляции-признаков-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Корреляции признаков</a></span></li><li><span><a href="#Анализ-отдельных-подгрупп" data-toc-modified-id="Анализ-отдельных-подгрупп-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Анализ отдельных подгрупп</a></span></li></ul></li><li><span><a href="#Кластерный-анализ" data-toc-modified-id="Кластерный-анализ-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Кластерный анализ</a></span></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></div>

# %% [markdown]
# ## Аннотация
#
# **Цель.** Выявить особенности реакции на психологический стресс и соответствующие компоненты структуры личности девушек-студенток медицианского вуза, выделить группы риска для оптимизации дальнейшей психотерапевтической помощи.
#
# **Задачи:**
# 1) изучить теоретические аспекты особенностей проявления эмоционально-психологического стресса у студентов;
# 2) изучить социально-психологический профиль студенток, в том числе гендерный тип и учебную мотивацию;
# 3) выявить основные стрессоры, уровень стресса и стрессоустойчивости;
# 4) проанализировать корреляционные связи изученных показателей;
# 5) провести кластерный анализ, выделить группы риска.
#
# **Материалы и методы.** С помощью бумажной [анкеты](https://disk.yandex.ru/i/boczlcgo1dyizg) проведено одномоментное исследование отдельных компонент социально-психологического профиля у $n=89$ студенток 2 курса медицинского вуза. Результаты анкетирования внесены в [файл](https://disk.yandex.ru/i/grcY51NUn4lMzQ).
#
# В анкету были включены вопросы о медико-социальном статусе студенток (лист `AG` файла) и тесты по следующим методикам:
# - [«Маскулинность, феминность и гендерный тип личности»](https://psytests.org/trait/bsriR.html) – валидизированный на российской выборке сокращенный вариант (аналог) Полоролевого опросника (S. Bem Sex Role Inventory, BSRI, 1974; адаптация О.Г. Лопухова, 2013) — лист `T1`;
# - [Краткая шкала академической мотивации, ШАМ](https://psytests.org/emvol/sham.html) (Т.О. Гордеева, О.А. Сычев, Е.Н. Осин, 2014) — лист `T2`;
# - [Опросник повседневных стрессоров](https://psytests.org/stress/opstress.html)  (М.Д. Петраш, О.Ю. Стрижицкая и др., 2018) — лист `T3`;
# - [Шкала психологического стресса Psychological Stress Measure, РSМ-25](https://psytests.org/stress/psm25r.html) (R. Tessier, L. Lemyre, L. Fillion, 1990; адаптация Н.Е. Водопьяновой, 2009) — лист `T4`;
# - [Тест на стрессоустойчивость](https://psytests.org/stress/shstress.html) (Ю.В. Щербатых, 2005) — лист `T5`.
#
# Для анализа статистической значимости различий использовали:
# - для количественных и ранговых показателейв в двух несвязанных выборках — *U*-критерий Манна-Уитни;
# - для номинальных показателей в двух или трех несвязанных выборках — критерий $χ^2$ Пирсона;
# - для количественных показателей в трех несвязанных выборках — *H*-критерий Краскелла-Уоллиса.
#
# Для всех критериев принят уровень статистической значимости $\alpha=0.05$.
#
# Для выявление связи между количественными или ранговыми признаками применялся коэффициент ранговой корреляции $\rho$ Спирмена; качественно силу корреляции оценивали по шкале Чеддока (слабая — $\rho<0.3$; умеренная — $0.3\le\rho<0.5$; заметная — $0.5\le\rho<0.7$; высокая — $0.7\le\rho<0.9$; сильная — $\rho\ge0.9$).
#
# Для выделения групп риска применялся алгоритм кластеризации — метод *k*-средних (без начальных центроидов), поиск оптимального числа кластеров осуществлялся методом локтя.

# %%
# подключение библиотек
import os
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import textwrap
from scipy.stats import spearmanr, pearsonr, kendalltau
from scipy.stats import mannwhitneyu as utest, kruskal as htest, chi2_contingency as chi2_test
from sklearn.cluster import KMeans

# %%
# отключить предупреждения о контроле версий бибилиотек
pd.set_option('future.no_silent_downcasting', True)

# константа рандомизации
RAND = 30417

# путь к файлу в сети
path = 'https://docs.google.com/spreadsheets/d/1LyFBVO-tHShepe_UrC3XWIefGx5_9dWMT5pfbIDQjDA/pub?output=xlsx'

# локальное имя файла
file = 'girl_stress.xlsx'

# %%
def corr_matrix_with_pval(df, method = 'pearson', figsize=(20, 10), title=None, fname=None):
  '''
  построение градиентной матрицы (хитмапа) корреляций
  с указанием статистической значимости (p-value)
  по источнику: https://readmedium.com/enhancing-correlation-matrix-heatmap-plots-with-p-values-in-python-41bac6a7fd77
  '''
  data = df.copy()
  corr = data.corr(method = method)
  
  # маска для сокрытия дублирующих данных над верхней диагональю
  mask = np.zeros_like(corr, dtype=bool)
  mask[np.triu_indices_from(mask)] = True
  
  # диагональные элементы ставим False для корректного отображения самокорреляций
  np.fill_diagonal(mask, False)
  fig, ax = plt.subplots(figsize=figsize)
  plt.title(title, fontsize=16, loc='left')

  # создание хитмапа
  heatmap = sns.heatmap(corr,
                        annot=True,
                        annot_kws={"fontsize": 10},
                        fmt='.2f',
                        linewidths=0.5,
                        cmap='RdBu',
                        mask=mask,
                        ax=ax)
    
  # подсчет и форматирование p-value
  p_values = np.full((corr.shape[0], corr.shape[1]), np.nan)
  for i in range(corr.shape[0]):
    for j in range(i+1, corr.shape[1]):
      x = data.iloc[:, i]
      y = data.iloc[:, j]
      mask = ~np.logical_or(np.isnan(x), np.isnan(y))
      if np.sum(mask) > 0:
        if method == 'pearson':
          p_values[i, j] = pearsonr(x[mask], y[mask])[1] #Changes based on the method chosen in the function
        elif method == 'kendall':
          p_values[i, j] = kendalltau(x[mask], y[mask])[1]
        elif method == 'spearman':
          p_values[i, j] = spearmanr(x[mask], y[mask])[1]
  p_values = pd.DataFrame(p_values, columns=corr.columns, index=corr.index)

  # маска для p-value
  mask_pvalues = np.triu(np.ones_like(p_values), k=1)

  # подсчет экстремумов корреляции
  max_corr = np.max(corr.max())
  min_corr = np.min(corr.min())
    
  # добавление p-value и настройка цветового градиента
  for i in range(p_values.shape[0]):
    for j in range(p_values.shape[1]):
      if mask_pvalues[i, j]:
        p_value = p_values.iloc[i, j]
        if not np.isnan(p_value):
          correlation_value = corr.iloc[i, j]
          text_color = 'white' if correlation_value >= (max_corr - 0.4) or correlation_value <= (min_corr + 0.4) else 'black'
          ax.text(i + 0.5, j + 0.8, f'(p = {p_value:.3f})',
                  horizontalalignment='center',
                  verticalalignment='center',
                  fontsize=8,
                  color=text_color)
        
  # подписи по горизонтали и вертикали
  x_labels = [textwrap.fill(label.get_text(), 13) for label in ax.get_xticklabels()]
  ax.set_xticklabels(x_labels, rotation=0, ha='center')
  y_labels = [textwrap.fill(label.get_text(), 13) for label in ax.get_yticklabels()]
  ax.set_yticklabels(y_labels, rotation=0, ha='right')

  # сохранение картинки в файл и отрисовка
  if fname != None:
    plt.savefig(fname, bbox_inches='tight')
  plt.savefig('tag1.png', bbox_inches='tight')
  plt.show()

# %% [markdown]
# ## Первичная обработка результатов анкетирования

# %%
def read_sheet(sh):
    '''чтение очередного листа из файла'''
    # на локальном компьютере с Windows
    if os.path.exists('datasets\\'+file):
        df = pd.read_excel('datasets\\'+file, sheet_name=sh)
    # в случае исполнения проекта на сервере Linux
    elif os.path.exists('/datasets/'+file):
        df = pd.read_excel('/datasets/'+file, sheet_name=sh)
    # в ином случае - скачать по сети
    else:
        try:
            df = pd.read_excel(path, sheet_name=sh)
        except:
            print('Невозможно загрузить файл с данными!')
    return df

# %% [markdown]
# ### Социально-психологические и медико-социальные характеристики
# Описание показателей:
# - ```PID``` — идентификатор (номер) записи;
# - ```Age``` — возраст девушки, лет;
# - ```Mena``` — менархе (возраст начала менструаций), лет (0 - нет);
# - ```Coita``` — коитархе (возраст начала половой жизни), лет (0 - нет);
# - ```Partn``` — наличие постоянного партнера (0 - нет, 1 - есть);
# - ```Auto``` — наличие автомобиля (0 - нет, 1 - есть);
# - ```Habit``` — проживание отдельно от родителей (0 - нет, 1 - да);
# - ```Kids``` — наличие детей (0 - нет, 1 - есть);
# - ```Anam``` — акушерско-гинекологический анамнез (наличие женских болезней) (0 - нет, 1 - да);
# - ```Mns_d``` — обычная длительность менструаций, дней (0 - нет);
# - ```Cyc_d``` — обычная длительность менструального цикла, дней (0 - нет);
# - ```Delay``` — существенные задержки менструации в анамнезе (0 - нет, 1 - есть);
# - ```Val``` — обычный объем менструальной крови (0 - норма, 1 - значительный);
# - ```Pain``` — субъективная оценка привычной альгоменореи (болезненности менструаций) (1 - слабая, 2 - средняя, 3 - сильная)

# %%
ag = read_sheet('AG')
ag.head(3)
# Out:
#    PID  Age  Mena  Coita  Partn  Auto  Habit  Kids  Anam  Mns_d  Cyc_d  Delay  \
# 0    1   19    12      0      0     0      1     0     0      3     24      0
# 1    2   19    14     18      0     0      0     0     1      4     32      0
# 2    3   20    14      0      0     0      1     0     0      5     28      0
#
#    Val  Pain
# 0    0     2
# 1    1     3
# 2    1     2

# %%
ag.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   PID     89 non-null     int64
#  1   Age     89 non-null     int64
#  2   Mena    89 non-null     int64
#  3   Coita   89 non-null     int64
#  4   Partn   89 non-null     int64
#  5   Auto    89 non-null     int64
#  6   Habit   89 non-null     int64
#  7   Kids    89 non-null     int64
#  8   Anam    89 non-null     int64
#  9   Mns_d   89 non-null     int64
#  10  Cyc_d   89 non-null     int64
#  11  Delay   89 non-null     int64
#  12  Val     89 non-null     int64
#  13  Pain    89 non-null     int64
# dtypes: int64(14)
# memory usage: 9.9 KB

# %% [markdown]
# **Вывод.** Пропусков данных в таблице нет

# %%
ag['Age'].value_counts(normalize=True)*100
# Out:
# Age
# 19    55.056180
# 20    19.101124
# 21     7.865169
# 22     4.494382
# 24     4.494382
# 23     2.247191
# 18     2.247191
# 25     2.247191
# 26     1.123596
# 27     1.123596
# Name: proportion, dtype: float64

# %%
ag['Age'].describe()
# Out:
# count    89.000000
# mean     20.078652
# std       1.835414
# min      18.000000
# 25%      19.000000
# 50%      19.000000
# 75%      20.000000
# max      27.000000
# Name: Age, dtype: float64

# %% [markdown]
# **Вывод.** Возраст большинства девушек $19-20$ лет, средний возраст $20\pm1.8$ лет.

# %%
mena_res = ag['Mena'].value_counts()
mena_res.index.name = 'index'
mena_res
# Out:
# index
# 13    24
# 11    19
# 12    18
# 14    15
# 15     6
# 10     2
# 17     2
# 16     2
# 9      1
# Name: count, dtype: int64

# %%
mena_res = pd.DataFrame(mena_res).sort_values(by=['index'])
mena_res
# Out:
#        count
# index
# 9          1
# 10         2
# 11        19
# 12        18
# 13        24
# 14        15
# 15         6
# 16         2
# 17         2

# %%
ag['Coita'].value_counts()
# Out:
# Coita
# 0     43
# 18    16
# 17    15
# 19     5
# 16     4
# 21     2
# 15     2
# 20     2
# Name: count, dtype: int64

# %% [markdown]
# Создадим поле `Coita_code` (начала вести половую жизнь - 1, нет - 0)

# %%
ag['Coita_code'] = pd.Series((ag['Coita'] > 0).replace({True: 1, False: 0}), dtype='int64')
ag['Coita_code'].head()
# Out:
# 0    0
# 1    1
# 2    0
# 3    1
# 4    1
# Name: Coita_code, dtype: int64

# %%
ag['Coita_code'].value_counts()
# Out:
# Coita_code
# 1    46
# 0    43
# Name: count, dtype: int64

# %% [markdown]
# Поскольку в исходном поле `Coita` максимальный возраст начала половой жизни равен 20, у девственниц значение 0 заменим на 25, чтобы сохранить смысловую зависимость, что важно для дальнейшего определения корреляций.

# %%
ag['Coita'] = ag['Coita'].replace(0, 25)
ag[ag['Coita'] < 25]['Coita'].describe()
# Out:
# count    46.000000
# mean     17.695652
# std       1.297340
# min      15.000000
# 25%      17.000000
# 50%      18.000000
# 75%      18.000000
# max      21.000000
# Name: Coita, dtype: float64

# %% [markdown]
# **Вывод.** Средний коитархе составляет $18\pm1.3$ лет.

# %%
coita_res = ag['Coita'].value_counts()
coita_res.index.name = 'index'
coita_res
# Out:
# index
# 25    43
# 18    16
# 17    15
# 19     5
# 16     4
# 21     2
# 15     2
# 20     2
# Name: count, dtype: int64

# %%
coita_res = pd.DataFrame(coita_res).sort_values(by=['index'])
coita_res.index = coita_res.index.map(str)
coita_res
# Out:
#        count
# index
# 15         2
# 16         4
# 17        15
# 18        16
# 19         5
# 20         2
# 21         2
# 25        43

# %%
coita_res.loc['не живут'] = coita_res.loc['25']
coita_res = coita_res.drop(['25'])
coita_res
# Out:
#           count
# index
# 15            2
# 16            4
# 17           15
# 18           16
# 19            5
# 20            2
# 21            2
# не живут     43

# %%
plt.figure(figsize=(12, 3)) 
plt.subplot(1, 2, 1)
plt.bar(mena_res.index, mena_res['count'], color='lightblue')
plt.xticks(mena_res.index)
plt.xlabel('Возраст, лет')
plt.ylabel('Кол-во девушек')
plt.title('Возраст начала менструаций (менархе)')

plt.subplot(1, 2, 2)
plt.bar(coita_res.index, coita_res['count'], color=['lightgreen']*7 + ['pink'] )
plt.text('не живут', 20, 
         f"{(coita_res.loc['не живут', 'count'] / coita_res['count'].sum()):.0%}", 
         horizontalalignment='center', fontsize=10)
plt.xticks(coita_res.index)
plt.xlabel('Возраст, лет')
plt.ylabel('Кол-во девушек')
plt.title('Возраст начала половой жизни (коитархе)')
plt.savefig('tag1.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# **Вывод.** Распределения менархе и коитархе близки к нормальным, при этом почти половина девушек пока не живут половой жизнью.

# %%
ag['Pain'].value_counts()
# Out:
# Pain
# 1    35
# 2    27
# 3    27
# Name: count, dtype: int64

# %%
pain_res = pd.DataFrame(ag['Pain'].value_counts())
pain_res['Pain_Level'] = pd.Series({1: 'слабая',
                                    2: 'средняя',
                                    3: 'сильная'})
pain_res
# Out:
#       count Pain_Level
# Pain
# 1        35     слабая
# 2        27    средняя
# 3        27    сильная

# %%
fig, ax = plt.subplots(figsize=(6,3))

wedges, texts, autotexts = ax.pie(x=pain_res['count'], 
                                  autopct='%1.1f%%',
                                  textprops={'fontsize':10},
                                  colors=['lightgreen', 'lightblue', 'pink'])
ax.legend(wedges, pain_res['Pain_Level'],
          title='Уровень боли:',
          loc='center left',
          bbox_to_anchor=(1, 0, 0.5, 1))
plt.title('Субъективная оценка менструальной боли', loc='left')
plt.savefig('tag2.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# **Вывод.** Распределения субъективных оценок альгоменореи равномерное, хотя доля девушек со слабой болью немногого больше.

# %%
# список показателей, отражающих социально-психологический статус
ag_vars = ['Mena', 'Coita', 'Coita_code', 'Pain',
           'Partn', 'Kids', 'Auto', 'Habit']

# %%
ag_res = ag[ag_vars].describe().loc[['mean', '50%', 'std']]
ag_res
# Out:
#            Mena      Coita  Coita_code      Pain     Partn      Kids  \
# mean  12.719101  21.224719    0.516854  1.910112  0.348315  0.022472
# 50%   13.000000  21.000000    1.000000  2.000000  0.000000  0.000000
# std    1.544703   3.786197    0.502547  0.834490  0.479136  0.149052
#
#           Auto     Habit
# mean  0.089888  0.516854
# 50%   0.000000  1.000000
# std   0.287641  0.502547

# %% [markdown]
# **Вывод.** Средний менархе составляет $13\pm1.5$ лет, средний уровень альгоменореи $1.9\pm0.83$ балла, начали половую жизнь $52\%$ девушек, при этом постоянный партнер есть у $35\%$ девушек, проживают отдельно от родителей $52\%$, автомобиль есть у $9\%$, дети только у $2\%$.

# %%
ag.groupby('Habit')['Coita_code'].value_counts(normalize=True)
# Out:
# Habit  Coita_code
# 0      1             0.511628
#        0             0.488372
# 1      1             0.521739
#        0             0.478261
# Name: proportion, dtype: float64

# %% [markdown]
# **Вывод.** В выборках девушек, проживающих вместе с родителями и отдельно от них, доли девственниц примерно равны и составляют примерно половину. Поэтому раздельное от родителей проживание не связано с фактом более раннего начала половой жизни.

# %%
# список показателей, отражающих медико-социальный статус
ag_med = ['Mns_d', 'Cyc_d', 'Anam', 'Delay', 'Val', 'Pain']

# %%
ag_med_res = ag[ag_med].describe().loc[['mean', '50%', 'std']]
ag_med_res
# Out:
#          Mns_d      Cyc_d      Anam     Delay       Val      Pain
# mean  5.516854  29.033708  0.224719  0.303371  0.157303  1.910112
# 50%   6.000000  28.000000  0.000000  0.000000  0.000000  2.000000
# std   1.235023   2.357047  0.419762  0.462319  0.366149  0.834490

# %% [markdown]
# **Вывод.** Средняя продолжительность менструаций составляет $6\pm1.2$ дней, средняя продолжительность менструального цикла $29\pm2.4$ дней, женские болезни имеются у $22\%$ девушек, существенные задержки цикла отмечались у $30\%$, объем менструальных выделений выше нормы у $16\%$.

# %%
corr_matrix_with_pval(ag[ag_vars], method = 'spearman', figsize=(10, 4))

# %% [markdown]
# **Вывод.** Естественная сильная корреляция между `Coita_code` и `Coita`, а также заметные корреляции этих показателей с `Partn` ожидаемы и не несут новой информации, других значимых корреляций среди социально-психологических показателей нет.

# %%
corr_matrix_with_pval(ag[ag_med], method = 'spearman', figsize=(8, 3))

# %% [markdown]
# **Вывод.** Умеренная корреляция показателей `Anam` и `Delay` ожидаема и не несет новой информации, других значимых корреляций среди медико-социальных показателей нет.

# %% [markdown]
# ### Маскулинность, феминность и гендерный тип личности
# [Описание](https://psytests.org/trait/bsriR.html)

# %%
t1 = read_sheet('T1')
t1.head(3)
# Out:
#    PID  T1_1  T1_2  T1_3  T1_4  T1_5  T1_6  T1_7  T1_8  T1_9  ...  T1_18  \
# 0    1     5     4     5     4     5     5     2     4     4  ...      5
# 1    2     4     4     4     4     5     4     2     5     4  ...      5
# 2    3     4     3     4     3     3     4     4     4     4  ...      5
#
#    T1_19  T1_20  T1_21  T1_22  T1_23  T1_24  T1_25  T1_26  T1_27
# 0      3      4      5      3      4      4      3      3      4
# 1      2      5      5      4      5      5      4      5      5
# 2      2      5      5      5      5      5      5      5      5
#
# [3 rows x 28 columns]

# %%
t1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 28 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   PID     89 non-null     int64
#  1   T1_1    89 non-null     int64
#  2   T1_2    89 non-null     int64
#  3   T1_3    89 non-null     int64
#  4   T1_4    89 non-null     int64
#  5   T1_5    89 non-null     int64
#  6   T1_6    89 non-null     int64
#  7   T1_7    89 non-null     int64
#  8   T1_8    89 non-null     int64
#  9   T1_9    89 non-null     int64
#  10  T1_10   89 non-null     int64
#  11  T1_11   89 non-null     int64
#  12  T1_12   89 non-null     int64
#  13  T1_13   89 non-null     int64
#  14  T1_14   89 non-null     int64
#  15  T1_15   89 non-null     int64
#  16  T1_16   89 non-null     int64
#  17  T1_17   89 non-null     int64
#  18  T1_18   89 non-null     int64
#  19  T1_19   89 non-null     int64
#  20  T1_20   89 non-null     int64
#  21  T1_21   89 non-null     int64
# ...

# %% [markdown]
# **Вывод.** Пропусков данных в таблице нет

# %%
t1['masc'] = t1[['T1_1', 'T1_4', 'T1_7', 'T1_10', 'T1_13', 'T1_16', 'T1_19', 'T1_22', 'T1_25']].sum(axis=1) - 27

# %%
t1['masc'].head()
# Out:
# 0    3
# 1    3
# 2    9
# 3    0
# 4    2
# Name: masc, dtype: int64

# %%
t1['fem'] = t1[['T1_2', 'T1_5', 'T1_8', 'T1_11', 'T1_14', 'T1_17', 'T1_20', 'T1_23', 'T1_26']].sum(axis=1) - 27

# %%
t1['fem'].head()
# Out:
# 0     9
# 1    16
# 2    12
# 3     2
# 4    13
# Name: fem, dtype: int64

# %%
t1['buf'] = t1[['T1_3', 'T1_6', 'T1_9', 'T1_12', 'T1_15', 'T1_18', 'T1_21', 'T1_24', 'T1_27']].sum(axis=1) - 27

# %%
t1['buf'].head()
# Out:
# 0    14
# 1    14
# 2    13
# 3    11
# 4    14
# Name: buf, dtype: int64

# %%
t1['gender'] = 'null'

# %%
t1.loc[t1[(t1['fem'] <= 0)&(t1['masc'] > 0)].index, 'gender'] = 'маскулинный'

# %%
t1[t1['gender'] == 'маскулинный']
# Out:
#     PID  T1_1  T1_2  T1_3  T1_4  T1_5  T1_6  T1_7  T1_8  T1_9  ...  T1_22  \
# 6     7     5     2     4     5     2     4     5     4     4  ...      4
# 29   30     4     2     3     4     4     5     3     2     3  ...      4
# 35   36     4     3     4     4     2     4     4     3     4  ...      4
#
#     T1_23  T1_24  T1_25  T1_26  T1_27  masc  fem  buf       gender
# 6       3      4      5      4      3    11   -2    6  маскулинный
# 29      2      4      4      3      4     6   -4    4  маскулинный
# 35      3      4      4      4      4     7    0    8  маскулинный
#
# [3 rows x 32 columns]

# %%
t1.loc[t1[(t1['fem'] > 0)&(t1['masc'] <= 0)].index, 'gender'] = 'феминный'

# %%
t1[t1['gender'] == 'феминный'].head(3)
# Out:
#     PID  T1_1  T1_2  T1_3  T1_4  T1_5  T1_6  T1_7  T1_8  T1_9  ...  T1_22  \
# 3     4     3     4     5     4     3     4     2     2     4  ...      2
# 13   14     4     4     4     4     4     4     4     4     4  ...      2
# 19   20     4     2     4     4     4     4     3     4     4  ...      2
#
#     T1_23  T1_24  T1_25  T1_26  T1_27  masc  fem  buf    gender
# 3       4      4      4      2      4     0    2   11  феминный
# 13      5      3      3      4      4     0    8    8  феминный
# 19      4      4      4      4      4    -1    2    7  феминный
#
# [3 rows x 32 columns]

# %%
t1.loc[t1[(t1['fem'] > 0)&(t1['masc'] > 0)].index, 'gender'] = 'андрогинный'

# %%
t1[t1['gender'] == 'андрогинный'].head(3)
# Out:
#    PID  T1_1  T1_2  T1_3  T1_4  T1_5  T1_6  T1_7  T1_8  T1_9  ...  T1_22  \
# 0    1     5     4     5     4     5     5     2     4     4  ...      3
# 1    2     4     4     4     4     5     4     2     5     4  ...      4
# 2    3     4     3     4     3     3     4     4     4     4  ...      5
#
#    T1_23  T1_24  T1_25  T1_26  T1_27  masc  fem  buf       gender
# 0      4      4      3      3      4     3    9   14  андрогинный
# 1      5      5      4      5      5     3   16   14  андрогинный
# 2      5      5      5      5      5     9   12   13  андрогинный
#
# [3 rows x 32 columns]

# %%
t1.loc[t1[(t1['fem'] < 0)&(t1['masc'] < 0)&(t1['buf'] > 0)].index, 'gender'] = 'недифференцированный'

# %%
t1[t1['gender'] == 'недифференцированный']
# Out:
#     PID  T1_1  T1_2  T1_3  T1_4  T1_5  T1_6  T1_7  T1_8  T1_9  ...  T1_22  \
# 11   12     4     4     4     4     2     4     2     2     5  ...      3
# 22   23     4     1     4     4     1     4     4     1     4  ...      4
#
#     T1_23  T1_24  T1_25  T1_26  T1_27  masc  fem  buf                gender
# 11      2      4      1      3      4    -1   -5    8  недифференцированный
# 22      4      4      1      1      4    -2  -13    7  недифференцированный
#
# [2 rows x 32 columns]

# %%
t1[t1['gender'] == 'null']
# Out:
#     PID  T1_1  T1_2  T1_3  T1_4  T1_5  T1_6  T1_7  T1_8  T1_9  ...  T1_22  \
# 14   15     4     3     3     2     2     3     2     3     3  ...      3
#
#     T1_23  T1_24  T1_25  T1_26  T1_27  masc  fem  buf  gender
# 14      2      2      3      3      3    -2   -4   -2    null
#
# [1 rows x 32 columns]

# %% [markdown]
# **Вывод.** У двух девушек отмечен недифференцированный и у одной неопределенный гендерный тип, учитывая такое малое количество неопределенный гендерный тип можно ообъединить с недифференцированным.

# %%
t1.loc[14, 'gender'] = 'недифференцированный'

# %%
genders = t1['gender'].value_counts()
genders
# Out:
# gender
# андрогинный             64
# феминный                19
# маскулинный              3
# недифференцированный     3
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(6,3))

wedges, texts, autotexts = ax.pie(x=genders, 
                                  autopct='%1.1f%%',
                                  textprops={'fontsize':8})
ax.legend(wedges, genders.index,
          title='Тип личности:',
          loc='center left',
          bbox_to_anchor=(1, 0, 0.5, 1))
plt.title('Результаты обработки методики «Маскулинность,\n феминность и гендерный тип личности»')
plt.savefig('t1.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# **Вывод.** У $72\%$ девушек андрогинный тип, у $21\%$ — феминный и только у $7\%$ — маскулинный либо недифференцированный.

# %%
# кодирование гендерного типа
t1['gender_code'] = t1['gender'].replace({'феминный': 3,
                                          'андрогинный': 2,
                                          'маскулинный': 1,
                                          'недифференцированный': 0})
t1['gender_code'].head()
# Out:
# 0    2
# 1    2
# 2    2
# 3    3
# 4    2
# Name: gender_code, dtype: object

# %%
t1['Pain'] = ag['Pain']
t1['Pain'].head(3)
# Out:
# 0    2
# 1    3
# 2    2
# Name: Pain, dtype: int64

# %%
t1.groupby('gender')['Pain'].mean().T
# Out:
# gender
# андрогинный             1.828125
# маскулинный             1.333333
# недифференцированный    2.666667
# феминный                2.157895
# Name: Pain, dtype: float64

# %%
pain_per_gender = pd.DataFrame(t1.groupby('gender').value_counts(
    ['Pain'], normalize=True, sort=False)*100)
pain_per_gender
# Out:
#                            proportion
# gender               Pain
# андрогинный          1      45.312500
#                      2      26.562500
#                      3      28.125000
# маскулинный          1      66.666667
#                      2      33.333333
# недифференцированный 2      33.333333
#                      3      66.666667
# феминный             1      21.052632
#                      2      42.105263
#                      3      36.842105

# %% [markdown]
# **Вывод.** Среди девушек феминного типа почти $80\%$ имеют средний или сильный уровень боли, среди девушек наиболее частого андрогинного типа таких $55\%$, маскулинного &ndash; лишь $33\%$.

# %% [markdown]
# ### Краткая шкала академической мотивации
# [Описание](https://psytests.org/emvol/sham.html)

# %%
t2 = read_sheet('T2')
t2.head(3)
# Out:
#    PID  T2_1  T2_2  T2_3  T2_4  T2_5  T2_6  T2_7  T2_8  T2_9  T2_10  T2_11  \
# 0    1     5     5     5     3     4     5     4     4     5      5      5
# 1    2     4     3     4     3     4     3     2     2     4      4      5
# 2    3     1     2     1     3     1     3     3     2     5      1      4
#
#    T2_12  T2_13  T2_14  T2_15  T2_16
# 0      3      5      5      5      1
# 1      4      5      5      5      1
# 2      2      1      3      1      4

# %%
t2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   PID     89 non-null     int64
#  1   T2_1    89 non-null     int64
#  2   T2_2    89 non-null     int64
#  3   T2_3    89 non-null     int64
#  4   T2_4    89 non-null     int64
#  5   T2_5    89 non-null     int64
#  6   T2_6    89 non-null     int64
#  7   T2_7    89 non-null     int64
#  8   T2_8    89 non-null     int64
#  9   T2_9    89 non-null     int64
#  10  T2_10   89 non-null     int64
#  11  T2_11   89 non-null     int64
#  12  T2_12   89 non-null     int64
#  13  T2_13   89 non-null     int64
#  14  T2_14   89 non-null     int64
#  15  T2_15   89 non-null     int64
#  16  T2_16   89 non-null     int64
# dtypes: int64(17)
# memory usage: 11.9 KB

# %% [markdown]
# **Вывод.** Пропусков данных в таблице нет

# %%
# процентный уровень познавательной мотивации
t2['cogn'] = t2[['T2_1', 'T2_5', 'T2_9', 'T2_13']].sum(axis=1) / 20 * 100

# %%
t2['cogn'].head()
# Out:
# 0     95.0
# 1     85.0
# 2     40.0
# 3     70.0
# 4    100.0
# Name: cogn, dtype: float64

# %%
# процентный уровень мотивации достижения
t2['achiev'] = t2[['T2_2', 'T2_6', 'T2_10', 'T2_14']].sum(axis=1) / 20 * 100

# %%
t2['achiev'].head()
# Out:
# 0    100.0
# 1     75.0
# 2     45.0
# 3     45.0
# 4    100.0
# Name: achiev, dtype: float64

# %%
# процентный уровень интроецированной мотивации
t2['intro'] = t2[['T2_3', 'T2_7', 'T2_11', 'T2_15']].sum(axis=1) / 20 * 100

# %%
t2['intro'].head()
# Out:
# 0    95.0
# 1    80.0
# 2    45.0
# 3    80.0
# 4    90.0
# Name: intro, dtype: float64

# %%
# процентный уровень экстернальной мотивации
t2['ext'] = t2[['T2_4', 'T2_8', 'T2_12', 'T2_16']].sum(axis=1) / 20 * 100

# %%
t2['ext'].head()
# Out:
# 0    55.0
# 1    50.0
# 2    55.0
# 3    70.0
# 4    75.0
# Name: ext, dtype: float64

# %%
# средний общий уровень мотивации
t2['av_motiv'] = t2[['cogn', 'achiev', 'intro', 'ext']].mean(axis=1)

# %%
t2['av_motiv'].head()
# Out:
# 0    86.25
# 1    72.50
# 2    46.25
# 3    66.25
# 4    91.25
# Name: av_motiv, dtype: float64

# %%
plt.figure(figsize=(6, 3)) 
t2['av_motiv'].hist(bins=100, alpha=0.5)
plt.xlabel('Уровень мотивации, %')
plt.ylabel('Кол-во ответов')
plt.suptitle('Средний уровень мотивации')
plt.savefig('t2a.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# **Вывод.** Средний уровень мотивации имеет псевдонормальное мультимодальное распределеие.

# %%
plt.figure(figsize=(12, 3)) 

plt.subplot(1, 2, 1)
t2['cogn'].hist(bins=30, alpha=0.5, label='Познавательная')
t2['achiev'].hist(bins=30, alpha=0.5, label='Достижения')
plt.yticks(range(0, 35, 5))
plt.xlabel('Уровень мотивации, %')
plt.ylabel('Кол-во ответов')
plt.legend()

plt.subplot(1, 2, 2)
t2['intro'].hist(bins=35, alpha=0.5, color='C12', label='Интроецированная')
t2['ext'].hist(bins=35, alpha=0.5, color='C14',label='Экстернальная')
plt.yticks(range(0, 25, 5))
plt.xlabel('Уровень мотивации, %')
plt.ylabel('Кол-во ответов')
plt.legend()

plt.suptitle('Результаты обработки методики «Краткая шкала академической мотивации»')
plt.savefig('t2b.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# **Вывод.** Распределения всех типов мотивации далеки от нормальных, распределение экстернальной мотивации похоже на би- или тримодальное.

# %%
motiv = ['cogn', 'achiev', 'intro', 'ext']
motiv_rus = ['Познавательная', 'Достижения', 'Интроецированная', 'Экстернальная']

# %%
t2_res = t2[motiv].describe().loc[['mean', '50%', 'std']]
t2_res.columns = motiv_rus
t2_res
# Out:
#       Познавательная  Достижения  Интроецированная  Экстернальная
# mean       82.865169   74.775281         73.089888      57.359551
# 50%        85.000000   75.000000         75.000000      55.000000
# std        17.020837   18.446947         14.971671      17.007517

# %%
fig, ax = plt.subplots(figsize=(7, 3)) 
bars = ax.bar(t2_res.columns, 
              round(t2_res.loc['mean'], 1), 
              width=0.4,
              yerr=[t2_res.loc['std'], t2_res.loc['std']], 
              color='skyblue',
              capsize=3)
ax.bar_label(bars, label_type='center')
plt.title('Средний процентный уровень мотивации по шкалам')
plt.savefig('t2c.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# **Вывод.** Наиболее высокий средний уровень у познавательной мотивации ($83\%$), наименьший — у экстернальной ($57\%$).

# %%
t2['max_motiv'] = t2[motiv].idxmax(axis=1)
t2['max_motiv'].head()
# Out:
# 0    achiev
# 1      cogn
# 2       ext
# 3     intro
# 4      cogn
# Name: max_motiv, dtype: object

# %%
t2['max_motiv'] = t2['max_motiv'].replace(motiv, motiv_rus)
t2['max_motiv'].head()
# Out:
# 0          Достижения
# 1      Познавательная
# 2       Экстернальная
# 3    Интроецированная
# 4      Познавательная
# Name: max_motiv, dtype: object

# %%
t2['max_motiv_code'] = t2['max_motiv'].replace(motiv_rus, [3, 2, 1, 0])
t2['max_motiv_code'].head()
# Out:
# 0    2
# 1    3
# 2    0
# 3    1
# 4    3
# Name: max_motiv_code, dtype: object

# %%
max_motiv = t2['max_motiv'].value_counts()
max_motiv
# Out:
# max_motiv
# Познавательная      63
# Интроецированная    19
# Экстернальная        4
# Достижения           3
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(6,3))

wedges, texts, autotexts = ax.pie(x=max_motiv, 
                                  autopct='%1.1f%%',
                                  textprops={'fontsize':8})
ax.legend(wedges, max_motiv.index,
          title='Тип мотивации:',
          loc='center left',
          bbox_to_anchor=(1, 0, 0.5, 1))
plt.title('Преобладающий тип мотивации', loc='left')
plt.savefig('t2d.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# **Вывод.** У $71\%$ девушек на первом местестоит познавательная мотивация, интроецированная — у $21\%$, а мотивация достижения либо экстернальня — то только у оставшихся $8\%$. При этом средний уровень мотивации достижения был выше, чем у интроецированной и эктернальной моивации, что может означать неосознанное сокрытие истинного типа моивации.

# %%
pd.plotting.scatter_matrix(t2[motiv + ['av_motiv']], figsize=(9, 9))
plt.show()

# %%
corr_matrix_with_pval(t2[motiv + ['av_motiv']], 
                      method = 'spearman', 
                      figsize=(9, 3))

# %% [markdown]
# **Вывод.** Средний общий уровень мотивации `av_motiv` высоко коррелирует со всеми типами мотивации, кроме экстернальной `ext`.

# %%
plt.figure(figsize=(12, 3)) 

plt.subplot(1, 2, 1)
plt.scatter(x=t2['cogn'], y=t2['achiev'], s=10, c='blue')
plt.text(50, 90, 
         f"r={spearmanr(t2['cogn'], t2['achiev'])[0]:.2f}", 
         fontsize=10)
plt.text(50, 85, 
         f"(p={spearmanr(t2['cogn'], t2['achiev'])[1]:.3f})",
         fontsize=10)
plt.xlabel('Познавательная, %')
plt.ylabel('Достижения, %')

plt.subplot(1, 2, 2)
plt.scatter(x=t2['ext'], y=t2['intro'], s=10, c='red')
plt.text(20, 90, 
         f"r={spearmanr(t2['ext'], t2['intro'])[0]:.2f}", 
         fontsize=10)
plt.text(20, 85, 
         f"(p={spearmanr(t2['ext'], t2['intro'])[1]:.3f})",
         fontsize=10)
plt.xlabel('Экстернальная, %')
plt.ylabel('Интроецированная, %')

plt.suptitle('Корреляция между различными шкалами мотивации')
plt.savefig('t2e.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# **Вывод.** Видно также, что уровни мотивации достижения и познавательной мотивации сильно коррелирует между собой, что может свидетельствовать о сцепленности их понимания в сознании студенток. Тогда как интроецированная и внешняя мотивация коррелируют умеренно и, вероятно, осознаются как раздельные.
#
# Для кластерного анализа можно взять только 2 показателя: `av_motiv` и `ext`, либо `cogn` и `ext`.

# %% [markdown]
# ### Опросник повседневных стрессоров
# [Описание](https://psytests.org/stress/opstress.html)

# %%
t3 = read_sheet('T3')
t3.head(3)
# Out:
#    PID  T3_1  T3_2  T3_3  T3_4  T3_5  T3_6  T3_7  T3_8  T3_9  ...  T3_46  \
# 0    1     4     9     9     0     4     4     0     1     9  ...      8
# 1    2     3     6     8     1     3     5     7     9    10  ...      0
# 2    3     0     1     2     3     1     4     6     6     5  ...      3
#
#    T3_47  T3_48  T3_49  T3_50  T3_51  T3_52  T3_53  T3_54  T3_55
# 0      4      9      5      2      2      0      2      5      4
# 1      3      0      0      0      0      0      0      7      9
# 2      3      3      3      3      1      1      3      3      1
#
# [3 rows x 56 columns]

# %%
t3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 56 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   PID     89 non-null     int64
#  1   T3_1    89 non-null     int64
#  2   T3_2    89 non-null     int64
#  3   T3_3    89 non-null     int64
#  4   T3_4    89 non-null     int64
#  5   T3_5    89 non-null     int64
#  6   T3_6    89 non-null     int64
#  7   T3_7    89 non-null     int64
#  8   T3_8    89 non-null     int64
#  9   T3_9    89 non-null     int64
#  10  T3_10   89 non-null     int64
#  11  T3_11   89 non-null     int64
#  12  T3_12   89 non-null     int64
#  13  T3_13   89 non-null     int64
#  14  T3_14   89 non-null     int64
#  15  T3_15   89 non-null     int64
#  16  T3_16   89 non-null     int64
#  17  T3_17   89 non-null     int64
#  18  T3_18   89 non-null     int64
#  19  T3_19   89 non-null     int64
#  20  T3_20   89 non-null     int64
#  21  T3_21   89 non-null     int64
# ...

# %% [markdown]
# **Вывод.** Пропусков данных в таблице нет

# %%
# сумма процентных баллов для стресоров типа "учеба (работа) / дела"
t3['job_business'] = t3[['T3_1', 'T3_2', 'T3_3', 'T3_4', 
                         'T3_5', 'T3_6', 'T3_9', 'T3_11', 
                         'T3_12', 'T3_42']].sum(axis=1)

# %%
t3['job_business'].head()
# Out:
# 0    56
# 1    41
# 2    36
# 3    55
# 4    16
# Name: job_business, dtype: int64

# %%
# сумма процентных баллов для стресоров типа "отношения с окружающими"
t3['relationships'] = t3[['T3_15', 'T3_16', 'T3_22', 
                          'T3_23', 'T3_24', 'T3_30', 
                          'T3_35', 'T3_36', 'T3_43']].sum(axis=1) / 90 * 100

# %%
t3['relationships'].head()
# Out:
# 0    22.222222
# 1    23.333333
# 2    46.666667
# 3    17.777778
# 4     7.777778
# Name: relationships, dtype: float64

# %%
# сумма процентных баллов для стресоров типа "нарушение планов"
t3['plans_failure'] = t3[['T3_29', 'T3_37', 'T3_39', 
                         'T3_41', 'T3_49']].sum(axis=1) / 50 * 100

# %%
t3['plans_failure'].head()
# Out:
# 0    38.0
# 1    26.0
# 2    46.0
# 3     8.0
# 4    30.0
# Name: plans_failure, dtype: float64

# %%
# сумма процентных баллов для стресоров типа "финансы"
t3['money'] = t3[['T3_28', 'T3_44', 'T3_45', 
                  'T3_46', 'T3_47', 'T3_54']].sum(axis=1) / 60 * 100

# %%
t3['money'].head()
# Out:
# 0    48.333333
# 1    21.666667
# 2    28.333333
# 3    35.000000
# 4    41.666667
# Name: money, dtype: float64

# %%
# сумма процентных баллов для стресоров типа "планирование"
t3['planning'] = t3[['T3_13', 'T3_38', 'T3_40', 
                     'T3_51', 'T3_52', 'T3_53']].sum(axis=1) / 60 * 100

# %%
t3['planning'].head()
# Out:
# 0    20.000000
# 1    18.333333
# 2    41.666667
# 3    15.000000
# 4     8.333333
# Name: planning, dtype: float64

# %%
# сумма процентных баллов для стресоров типа "семья"
t3['family'] = t3[['T3_13', 'T3_14', 'T3_18', 
                   'T3_19', 'T3_20', 'T3_25']].sum(axis=1) / 60 * 100

# %%
t3['family'].head()
# Out:
# 0     5.000000
# 1    20.000000
# 2    43.333333
# 3    26.666667
# 4    10.000000
# Name: family, dtype: float64

# %%
# сумма процентных баллов для стресоров типа "окружающая обстановка"
t3['environment'] = t3[['T3_21', 'T3_32', 'T3_34', 
                        'T3_49', 'T3_50']].sum(axis=1) / 50 * 100

# %%
t3['environment'].head()
# Out:
# 0    26.0
# 1    16.0
# 2    46.0
# 3     0.0
# 4    36.0
# Name: environment, dtype: float64

# %%
# сумма процентных баллов для стресоров типа "одиночество"
t3['loneliness'] = t3[['T3_17', 'T3_27', 'T3_33', 
                       'T3_34', 'T3_55']].sum(axis=1) / 50 * 100

# %%
t3['loneliness'].head()
# Out:
# 0    44.0
# 1    58.0
# 2    30.0
# 3    44.0
# 4    18.0
# Name: loneliness, dtype: float64

# %%
# сумма процентных баллов для стресоров типа "самочувствие"
t3['well_being'] = t3[['T3_25', 'T3_31', 'T3_33', 
                       'T3_42', 'T3_48']].sum(axis=1) / 50 * 100

# %%
t3['well_being'].head()
# Out:
# 0    68.0
# 1    50.0
# 2    44.0
# 3    14.0
# 4    32.0
# Name: well_being, dtype: float64

# %%
# сумма процентных баллов для стресоров типа "конкуренция"
t3['competition'] = t3[['T3_7', 'T3_8', 'T3_10', 
                         'T3_26', 'T3_27']].sum(axis=1) / 50 * 100

# %%
t3['competition'].head()
# Out:
# 0    22.0
# 1    58.0
# 2    64.0
# 3    28.0
# 4    30.0
# Name: competition, dtype: float64

# %%
stressors = ['job_business', 'relationships', 'plans_failure', 'money', 'planning',
             'family', 'environment', 'loneliness', 'well_being', 'competition']
stress_rus = ['Учеба (работа) / дела', 'Взаимоотношения с окружающими', 'Нарушение планов', 
              'Финансы', 'Планирование', 'Семья', 'Окружающая действительность', 
              'Самочувствие / одиночество', 'Общее самочувствие', 'Конкуренция']

# %%
plt.figure(figsize=(12, 12)) 
for i in list(range(1,11)):
    plt.subplot(5, 2, i)
    t3[stressors[i-1]].hist(bins=45, alpha=0.5, label=stress_rus[i-1])
    plt.xlabel('Уровень стрессора, %')
    plt.ylabel('Кол-во ответов')
    plt.legend()
plt.suptitle('Результаты обработки методики «Опросник повседневных стрессоров»')
plt.savefig('t3a.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# **Вывод**. Распределение уровня стрессоров "Учеба (работа) / дела" и "Конкуренция" похожи на бимодальные, остальные стрессоры распределены неопределенным образом.

# %%
# средний уровень процентных баллов стрессоров
t3['av_stress'] = t3[stressors].mean(axis=1)

# %%
t3['av_stress'].head()
# Out:
# 0    34.955556
# 1    33.233333
# 2    42.600000
# 3    24.344444
# 4    22.977778
# Name: av_stress, dtype: float64

# %%
corr_matrix_with_pval(t3[stressors + ['av_stress']], 
                      method = 'spearman', 
                      figsize=(18, 6))

# %% [markdown]
# **Вывод**. Уровни большинства стрессоров заметно или высоко коррелируют между собой, при этом средний уровень процентных баллов стрессоров `av_motiv` высоко или сильно коррелирует со всеми остальными, этот показатель можно использовать для кластерного анализа.

# %%
plt.figure(figsize=(6, 3)) 
t3['av_stress'].hist(bins=35, alpha=0.5)
plt.xlabel('Уровень стрессора, %')
plt.ylabel('Кол-во ответов')
plt.suptitle('Средний уровень стрессоров')
plt.savefig('t3b.png', bbox_inches='tight')
plt.show()

# %%
t3['av_stress'].describe()
# Out:
# count    89.000000
# mean     30.464919
# std      17.424093
# min       1.200000
# 25%      18.066667
# 50%      28.144444
# 75%      43.733333
# max      73.933333
# Name: av_stress, dtype: float64

# %% [markdown]
# **Вывод**. Распределение среднего уровня стрессоров близко к нормальному со смещением влево, поэтому следует ожидать у большинства студенток среднего или слабого уровня общего стресса.

# %%
t3['max_stressor'] = t3[stressors].idxmax(axis=1)
t3['max_stressor'].head()
# Out:
# 0      well_being
# 1      loneliness
# 2     competition
# 3    job_business
# 4           money
# Name: max_stressor, dtype: object

# %%
t3['max_stressor'] = t3['max_stressor'].replace(stressors, stress_rus)
t3['max_stressor'].head()
# Out:
# 0            Общее самочувствие
# 1    Самочувствие / одиночество
# 2                   Конкуренция
# 3         Учеба (работа) / дела
# 4                       Финансы
# Name: max_stressor, dtype: object

# %%
t3_res = t3[stressors].describe().loc[['mean', '50%', 'std']]
t3_res.columns = stress_rus
t3_res = t3_res.sort_values(by='mean', axis=1, ascending=False)
t3_res
# Out:
#       Учеба (работа) / дела  Общее самочувствие  Конкуренция  \
# mean              38.415730           37.011236    33.842697
# 50%               38.000000           34.000000    30.000000
# std               18.193911           21.288331    21.520022
#
#       Нарушение планов  Самочувствие / одиночество    Финансы  \
# mean         31.910112                   29.887640  29.456929
# 50%          30.000000                   26.000000  28.333333
# std          20.615330                   21.132396  21.689637
#
#       Взаимоотношения с окружающими  Планирование      Семья  \
# mean                      27.915106     26.123596  25.299625
# 50%                       25.555556     21.666667  20.000000
# std                       19.205473     19.806155  20.881099
#
#       Окружающая действительность
# mean                    24.786517
# 50%                     24.000000
# std                     19.077874

# %%
fig, ax = plt.subplots(figsize=(4, 8)) 
bars = ax.barh(y=t3_res.columns, 
               width=round(t3_res.loc['mean'], 1), 
               height=0.5, 
               xerr=[0.5*t3_res.loc['std'], 
                     0.5*t3_res.loc['std']], 
               color='pink',
               capsize=3)
ax.bar_label(bars, label_type='center')
plt.title('Средний процентный уровень стрессоров')
plt.savefig('t3c.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# **Вывод**. Наибольший средний процентный уровень у стрессоров типа "Учеба (работа) / дела", "Самочувствие", "Конкуренция", что подтверждается выше обнаруженным высоким уровнем мотивации достижения и свидетельствует о значимости учебной профессиональной  деятельности чтуденток, а также о негативном влиянии соответствующих эмоций на самочувствие. При этом средние значения остальных стрессоров равномерно убывают от $32$ до $25\%$, т.е. нет других как преобладающих, так и незначительных  стрессоров.

# %%
t3['max_stressor_code'] = t3['max_stressor'].replace(stress_rus, list(np.arange(9, -1, -1)))
t3['max_stressor_code'].head()
# Out:
# 0    1
# 1    2
# 2    0
# 3    9
# 4    6
# Name: max_stressor_code, dtype: object

# %%
max_stressor = t3['max_stressor'].value_counts()
max_stressor
# Out:
# max_stressor
# Учеба (работа) / дела            25
# Общее самочувствие               16
# Конкуренция                      13
# Финансы                          13
# Нарушение планов                  8
# Взаимоотношения с окружающими     5
# Семья                             3
# Самочувствие / одиночество        2
# Планирование                      2
# Окружающая действительность       2
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(6,3))

wedges, texts, autotexts = ax.pie(x=max_stressor, 
                                  autopct='%1.0f%%',
                                  textprops={'fontsize':8})
ax.legend(wedges, max_stressor.index,
          title='Стрессоры:',
          loc='center left',
          bbox_to_anchor=(1, 0, 0.5, 1))
plt.title('Главный стрессор')
plt.savefig('t3d.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# **Вывод**. Почти у $30\%$ студенток главным стрессором является "Учеба (работа) / дела", почти у $20\%$ на 1 месте стрессор  "Общее самочувствие", еще по $15\%$ девушек прежде всего выделяют стрессоры "Конкуренция" или "Финансы". И менее, чем у $10\%$ на 1 месте стрессоры, связанные с личными или семейными отношениями. Это подтверждает преобладающую роль учебной деятельности и соответствующих пережеиваний.

# %% [markdown]
# ### Шкала психологического стресса (*РSМ-25*)
# [Описание](https://psytests.org/stress/psm25r.html)

# %%
t4 = read_sheet('T4')
t4.head(3)
# Out:
#    PID  T4_1  T4_2  T4_3  T4_4  T4_5  T4_6  T4_7  T4_8  T4_9  ...  T4_16  \
# 0    1     5     3     4     5     7     4     3     3     2  ...      3
# 1    2     6     7     7     4     5     7     7     7     6  ...      7
# 2    3     1     2     3     2     3     2     3     2     3  ...      5
#
#    T4_17  T4_18  T4_19  T4_20  T4_21  T4_22  T4_23  T4_24  T4_25
# 0      5      3      4      3      3      5      8      2      3
# 1      8      6      8      7      5      6      3      5      8
# 2      7      4      2      4      5      1      3      5      6
#
# [3 rows x 26 columns]

# %%
t4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 26 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   PID     89 non-null     int64
#  1   T4_1    89 non-null     int64
#  2   T4_2    89 non-null     int64
#  3   T4_3    89 non-null     int64
#  4   T4_4    89 non-null     int64
#  5   T4_5    89 non-null     int64
#  6   T4_6    89 non-null     int64
#  7   T4_7    89 non-null     int64
#  8   T4_8    89 non-null     int64
#  9   T4_9    89 non-null     int64
#  10  T4_10   89 non-null     int64
#  11  T4_11   89 non-null     int64
#  12  T4_12   89 non-null     int64
#  13  T4_13   89 non-null     int64
#  14  T4_14   89 non-null     int64
#  15  T4_15   89 non-null     int64
#  16  T4_16   89 non-null     int64
#  17  T4_17   89 non-null     int64
#  18  T4_18   89 non-null     int64
#  19  T4_19   89 non-null     int64
#  20  T4_20   89 non-null     int64
#  21  T4_21   89 non-null     int64
# ...

# %% [markdown]
# **Вывод.** Пропусков данных в таблице нет

# %%
t4['T4_14'].head()
# Out:
# 0    6
# 1    2
# 2    6
# 3    1
# 4    6
# Name: T4_14, dtype: int64

# %%
# инверсия баллов вопроса №14 в соответствии с инструкцией
t4['T4_14'] = 8 - t4['T4_14']
t4['T4_14'].head()
# Out:
# 0    2
# 1    6
# 2    2
# 3    7
# 4    2
# Name: T4_14, dtype: int64

# %%
# общая сумма баллов, без учета идентификатора
t4['psm_25_stress'] = t4.sum(axis=1) - t4['PID']
t4['psm_25_stress'].head()
# Out:
# 0     92
# 1    153
# 2     77
# 3    162
# 4     44
# Name: psm_25_stress, dtype: int64

# %%
def stress_indicator(p):
    if p > 155:
        return ('высокий', 3)
    elif p >= 100:
        return ('средний', 2)
    else:
        return ('низкий', 1)

# %%
t4['psm_25'] = t4['psm_25_stress'].apply(lambda x: stress_indicator(x)[0])
t4['psm_25'].head()
# Out:
# 0     низкий
# 1    средний
# 2     низкий
# 3    высокий
# 4     низкий
# Name: psm_25, dtype: object

# %%
t4['psm_25_code'] = t4['psm_25_stress'].apply(lambda x: stress_indicator(x)[1])
t4['psm_25_code'].head()
# Out:
# 0    1
# 1    2
# 2    1
# 3    3
# 4    1
# Name: psm_25_code, dtype: int64

# %%
# эффективность кодирования
corr_matrix_with_pval(t4[['psm_25_code', 'psm_25_stress']], 
                      method = 'spearman', 
                      figsize=(4, 2))

# %%
psm_25_res = t4['psm_25'].value_counts()
psm_25_res
# Out:
# psm_25
# низкий     60
# средний    27
# высокий     2
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(6,3))

wedges, texts, autotexts = ax.pie(x=psm_25_res, 
                                  autopct='%1.1f%%',
                                  textprops={'fontsize':10},
                                  colors=['lightgreen', 'orange', 'red'])
ax.legend(wedges, psm_25_res.index,
          title='Уровень стресса:',
          loc='center left',
          bbox_to_anchor=(1, 0, 0.5, 1))
plt.title('Результаты обработки методики\n «Шкала психологического стресса (РSМ-25)»')
plt.savefig('t4a.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# **Вывод**. У $67\%$ студенток отмечается низкий уровень стресса по методике *PSM-25*, незначительный процент имеют высокий уровеньстресса, поэтому при выполнении кластерного анализа студенток со средним/высоким уровнем стресса можно рассматривать как одну группу.

# %%
t4['psm_25_me_hi'] = t4['psm_25_code'].replace([3, 2, 1],
                                               [1, 1, 0])
t4['psm_25_me_hi'].value_counts()
# Out:
# psm_25_me_hi
# 0    60
# 1    29
# Name: count, dtype: int64

# %%
t2['psm_25_me_hi'] = t4['psm_25_me_hi']
t2['psm_25_me_hi'].head()
# Out:
# 0    0
# 1    1
# 2    0
# 3    1
# 4    0
# Name: psm_25_me_hi, dtype: int64

# %%
psm_25_motiv = t2.groupby('psm_25_me_hi')[motiv].mean().T
psm_25_motiv
# Out:
# psm_25_me_hi          0          1
# cogn          85.750000  76.896552
# achiev        76.916667  70.344828
# intro         72.833333  73.620690
# ext           54.083333  64.137931

# %%
psm_25_motiv['p-value'] = 0.0
for x in motiv:
    psm_25_motiv.loc[x, 'p-value'] = round(utest(t2.query('psm_25_me_hi==0')[x], 
                                                 t2.query('psm_25_me_hi==1')[x]).pvalue, 3)
psm_25_motiv
# Out:
# psm_25_me_hi          0          1  p-value
# cogn          85.750000  76.896552    0.019
# achiev        76.916667  70.344828    0.108
# intro         72.833333  73.620690    0.867
# ext           54.083333  64.137931    0.011

# %% [markdown]
# **Вывод**. У студенток с высоки уровнем стресса значимо ниже средний уровень познавтельной мотивации ($77\%$ против $86\%$) и значимо выше средний уровень экстернальной мотивации ($64\%$ против $54\%$); два других типа мотивации существенно не зависят от уровня стресса

# %%
t3['psm_25_me_hi'] = t4['psm_25_me_hi']
t3['psm_25_me_hi'].head()
# Out:
# 0    0
# 1    1
# 2    0
# 3    1
# 4    0
# Name: psm_25_me_hi, dtype: int64

# %%
psm_25_max_stressors = t3.groupby('psm_25_me_hi')['max_stressor'].value_counts()
psm_25_max_stressors
# Out:
# psm_25_me_hi  max_stressor
# 0             Учеба (работа) / дела            17
#               Общее самочувствие               11
#               Конкуренция                      10
#               Финансы                           8
#               Нарушение планов                  5
#               Взаимоотношения с окружающими     3
#               Семья                             3
#               Планирование                      2
#               Окружающая действительность       1
# 1             Учеба (работа) / дела             8
#               Общее самочувствие                5
#               Финансы                           5
#               Конкуренция                       3
#               Нарушение планов                  3
#               Взаимоотношения с окружающими     2
#               Самочувствие / одиночество        2
#               Окружающая действительность       1
# Name: count, dtype: int64

# %%
fig, axs = plt.subplots(1, 2, figsize=(6,3))
fig.suptitle('Главные стрессоры у девушек с низким и средним/высоким уровнем стресса по PSM-25', 
             x=0.75, y=1.05) # ha='right')
axs[0].pie(x=psm_25_max_stressors.loc[0], 
           autopct='%1.0f%%',
           textprops={'fontsize':8})
axs[0].set_title('Низкий уровень стресса', fontsize=8)
axs[0].legend(max_stressor.index,
              title='Стрессоры:',
              loc='center left',
              bbox_to_anchor=(2.3, 0.5),
              fontsize=8)
axs[1].pie(x=psm_25_max_stressors.loc[1], 
           autopct='%1.0f%%',
           textprops={'fontsize':8})
axs[1].set_title('Средний/высокий уровень стресса', fontsize=8)
plt.savefig('t4b.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# **Вывод.** Распределения указанных в предыдущей методике стрессоров как главных в группах девушек с низким и средним/высоким уровнем стресса по методике *PSM-25* существенно не различаются. Таким образом, у студенток, по-видимому, сила переживаемого  стресса не связана с преобладанием конкретного стрессора.

# %%
t3['Anam'] = ag['Anam']
t3['Delay'] = ag['Delay']
t3['Val'] = ag['Val']

# %%
psm_25_ag = t3.groupby('psm_25_me_hi')[['Anam', 'Delay','Val']].mean().T
psm_25_ag
# Out:
# psm_25_me_hi         0         1
# Anam          0.166667  0.344828
# Delay         0.283333  0.344828
# Val           0.150000  0.172414

# %%
psm_25_ag['p-value'] = 0.0
for x in ['Anam', 'Delay','Val']:
    psm_25_ag.loc[x, 'p-value'] = round(utest(t3.query('psm_25_me_hi==0')[x], 
                                              t3.query('psm_25_me_hi==1')[x]).pvalue, 3)
psm_25_ag
# Out:
# psm_25_me_hi         0         1  p-value
# Anam          0.166667  0.344828    0.061
# Delay         0.283333  0.344828    0.560
# Val           0.150000  0.172414    0.792

# %% [markdown]
# **Вывод.** У девушек со средним/высоким уровнем стресса в 2 раза чаще встречаются женские болезни по сравнению с девушками, у которых уровень стресса низкий ($34\%$ и $17\%$ соответственно; различие почти на уровне статистической значимости). Задержки цикла в анамнезе и объем менструальных выделений статистически значимо не различаются.

# %% [markdown]
# ### Тест на стрессоустойчивость
# [Описание](https://psytests.org/stress/shstress.html)

# %%
t5 = read_sheet('T5')
t5.head(3)
# Out:
#    PID  T5_1  T5_2  T5_3  T5_4  T5_5  T5_6  T5_7  T5_8  T5_9  ...  T5_17  \
# 0    1     6     8     6     6     1    10    10     8     2  ...      1
# 1    2     3     1     2     3     1     8    10     9    10  ...      1
# 2    3     1     2     3     8     5     1     3     5     4  ...      6
#
#    T5_18  T5_19  T5_20  T5_21  T5_22  T5_23  T5_24  T5_25  T5_26
# 0      7      8      3      8      3      7     10      5      4
# 1      1      5      3      8      9     10     10     10      4
# 2      3      8      3      7      9      3      3      8      5
#
# [3 rows x 27 columns]

# %%
t5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 27 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   PID     89 non-null     int64
#  1   T5_1    89 non-null     int64
#  2   T5_2    89 non-null     int64
#  3   T5_3    89 non-null     int64
#  4   T5_4    89 non-null     int64
#  5   T5_5    89 non-null     int64
#  6   T5_6    89 non-null     int64
#  7   T5_7    89 non-null     int64
#  8   T5_8    89 non-null     int64
#  9   T5_9    89 non-null     int64
#  10  T5_10   89 non-null     int64
#  11  T5_11   89 non-null     int64
#  12  T5_12   89 non-null     int64
#  13  T5_13   89 non-null     int64
#  14  T5_14   89 non-null     int64
#  15  T5_15   89 non-null     int64
#  16  T5_16   89 non-null     int64
#  17  T5_17   89 non-null     int64
#  18  T5_18   89 non-null     int64
#  19  T5_19   89 non-null     int64
#  20  T5_20   89 non-null     int64
#  21  T5_21   89 non-null     int64
# ...

# %% [markdown]
# **Вывод.** Пропусков данных в таблице нет

# %%
#  уровень фрустрации
t5['frustrat'] = t5[['T5_1', 'T5_2', 'T5_3', 'T5_4', 'T5_5']].sum(axis=1)

# %%
t5['frustrat'].head()
# Out:
# 0    27
# 1    10
# 2    19
# 3    10
# 4    24
# Name: frustrat, dtype: int64

# %%
def frustrat_indicator(f):
    if f > 30:
        return ('высокая', 3)
    elif f >= 15:
        return ('средняя', 2)
    else:
        return ('низкая', 1)

# %%
t5['frustrat_ind'] = t5['frustrat'].apply(lambda x: frustrat_indicator(x)[0])
t5['frustrat_ind'].head()
# Out:
# 0    средняя
# 1     низкая
# 2    средняя
# 3     низкая
# 4    средняя
# Name: frustrat_ind, dtype: object

# %%
t5['frustrat_code'] = t5['frustrat'].apply(lambda x: frustrat_indicator(x)[1])
t5['frustrat_code'].head()
# Out:
# 0    2
# 1    1
# 2    2
# 3    1
# 4    2
# Name: frustrat_code, dtype: int64

# %%
frustrat_res = t5['frustrat_ind'].value_counts()
frustrat_res
# Out:
# frustrat_ind
# средняя    43
# низкая     27
# высокая    19
# Name: count, dtype: int64

# %%
# уровень перфекционизма
t5['perf'] = t5[['T5_6', 'T5_7', 'T5_8', 'T5_9', 'T5_10']].sum(axis=1)

# %%
t5['perf'].head()
# Out:
# 0    35
# 1    47
# 2    19
# 3    38
# 4    21
# Name: perf, dtype: int64

# %%
def perf_indicator(p):
    if p > 25:
        return ('высокий', 3)
    elif p >= 14:
        return ('средний', 2)
    else:
        return ('низкий', 1)

# %%
t5['perf_ind'] = t5['perf'].apply(lambda x: perf_indicator(x)[0])
t5['perf_ind'].head()
# Out:
# 0    высокий
# 1    высокий
# 2    средний
# 3    высокий
# 4    средний
# Name: perf_ind, dtype: object

# %%
t5['perf_code'] = t5['perf'].apply(lambda x: perf_indicator(x)[1])
t5['perf_code'].head()
# Out:
# 0    3
# 1    3
# 2    2
# 3    3
# 4    2
# Name: perf_code, dtype: int64

# %%
perf_res = t5['perf_ind'].value_counts()
perf_res
# Out:
# perf_ind
# средний    43
# высокий    29
# низкий     17
# Name: count, dtype: int64

# %%
# уровень склонности к психосоматическим расстройствам
t5['psychosom'] = t5[['T5_11', 'T5_12', 'T5_13', 'T5_14', 'T5_15']].sum(axis=1)

# %%
t5['psychosom'].head()
# Out:
# 0    15
# 1    39
# 2    20
# 3    31
# 4    17
# Name: psychosom, dtype: int64

# %%
def psychosom_indicator(ps):
    if ps > 28:
        return ('высокая', 3)
    elif ps >= 12:
        return ('средняя', 2)
    else:
        return ('низкая', 1)

# %%
t5['psychosom_ind'] = t5['psychosom'].apply(lambda x: psychosom_indicator(x)[0])
t5['psychosom_ind'].head()
# Out:
# 0    средняя
# 1    высокая
# 2    средняя
# 3    высокая
# 4    средняя
# Name: psychosom_ind, dtype: object

# %%
t5['psychosom_code'] = t5['psychosom'].apply(lambda x: psychosom_indicator(x)[1])
t5['psychosom_code'].head()
# Out:
# 0    2
# 1    3
# 2    2
# 3    3
# 4    2
# Name: psychosom_code, dtype: int64

# %%
psychosom_res = t5['psychosom_ind'].value_counts()
psychosom_res
# Out:
# psychosom_ind
# средняя    50
# низкая     31
# высокая     8
# Name: count, dtype: int64

# %%
# уровень склонности к деструктивным (аддиктивным) способам преодоления стресса
t5['destr_overcom'] = t5[['T5_16', 'T5_17', 'T5_18', 'T5_19', 'T5_20']].sum(axis=1)

# %%
t5['destr_overcom'].head()
# Out:
# 0    20
# 1    12
# 2    22
# 3    25
# 4    12
# Name: destr_overcom, dtype: int64

# %%
def destr_overcom_indicator(d):
    if d > 22:
        return ('высокий', 3)
    elif d >= 10:
        return ('средний', 2)
    else:
        return ('низкий', 1)

# %%
t5['destr_overcom_ind'] = t5['destr_overcom'].apply(lambda x: destr_overcom_indicator(x)[0])
t5['destr_overcom_ind'].head()
# Out:
# 0    средний
# 1    средний
# 2    средний
# 3    высокий
# 4    средний
# Name: destr_overcom_ind, dtype: object

# %%
t5['destr_overcom_code'] = t5['destr_overcom'].apply(lambda x: destr_overcom_indicator(x)[1])
t5['destr_overcom_code'].head()
# Out:
# 0    2
# 1    2
# 2    2
# 3    3
# 4    2
# Name: destr_overcom_code, dtype: int64

# %%
destr_overcom_res = t5['destr_overcom_ind'].value_counts()
destr_overcom_res
# Out:
# destr_overcom_ind
# средний    59
# высокий    23
# низкий      7
# Name: count, dtype: int64

# %%
# уровень склонности к конструктивным (здоровым) способам преодоления стресса
t5['constr_overcom'] = t5[['T5_21', 'T5_22', 'T5_23', 'T5_24', 'T5_25']].sum(axis=1)

# %%
t5['constr_overcom'].head()
# Out:
# 0    33
# 1    47
# 2    30
# 3    45
# 4    40
# Name: constr_overcom, dtype: int64

# %%
def constr_overcom_indicator(c):
    if c > 35:
        return ('высокий', 3)
    elif c >= 23:
        return ('средний', 2)
    else:
        return ('низкий', 1)

# %%
t5['constr_overcom_ind'] = t5['constr_overcom'].apply(lambda x: constr_overcom_indicator(x)[0])
t5['constr_overcom_ind'].head()
# Out:
# 0    средний
# 1    высокий
# 2    средний
# 3    высокий
# 4    высокий
# Name: constr_overcom_ind, dtype: object

# %%
t5['constr_overcom_code'] = t5['constr_overcom'].apply(lambda x: constr_overcom_indicator(x)[1])
t5['constr_overcom_code'].head()
# Out:
# 0    2
# 1    3
# 2    2
# 3    3
# 4    3
# Name: constr_overcom_code, dtype: int64

# %%
constr_overcom_res = t5['constr_overcom_ind'].value_counts()
constr_overcom_res
# Out:
# constr_overcom_ind
# средний    42
# низкий     29
# высокий    18
# Name: count, dtype: int64

# %%
t5['T5_26'].head()
# Out:
# 0    4
# 1    4
# 2    5
# 3    5
# 4    4
# Name: T5_26, dtype: int64

# %%
# смысл показателя - динамика уровня стресса за последние 3 года 
t5.rename(columns={'T5_26': 'stress_dynam_code'}, inplace=True)
t5['stress_dynam_code'].head()
# Out:
# 0    4
# 1    4
# 2    5
# 3    5
# 4    4
# Name: stress_dynam_code, dtype: int64

# %%
# назначение соответствующих баллов в соответствии с инструкцией
t5['stress_dynam'] = t5['stress_dynam_code'].replace({1: -20,
                                                      2: -10,
                                                      3: 0,
                                                      4: 10,
                                                      5: 50})
t5['stress_dynam'].head()
# Out:
# 0    10
# 1    10
# 2    50
# 3    50
# 4    10
# Name: stress_dynam, dtype: int64

# %%
t5['stress_dynam_ind'] = t5['stress_dynam_code'].replace({1: 'значительно уменьшился',
                                                          2: 'незначительно уменьшился',
                                                          3: 'не изменился',
                                                          4: 'незначительно возрос',
                                                          5: 'значительно увеличился'})
t5['stress_dynam_ind'].head()
# Out:
# 0      незначительно возрос
# 1      незначительно возрос
# 2    значительно увеличился
# 3    значительно увеличился
# 4      незначительно возрос
# Name: stress_dynam_ind, dtype: object

# %%
stress_dynam_res = t5['stress_dynam_ind'].value_counts()
stress_dynam_res
# Out:
# stress_dynam_ind
# незначительно возрос        36
# значительно увеличился      24
# не изменился                18
# незначительно уменьшился     7
# значительно уменьшился       4
# Name: count, dtype: int64

# %%
# базовая стрессочувствительность
t5['basic_stress_sensitiv'] = t5[['frustrat', 'perf', 'psychosom', 'destr_overcom']].sum(axis=1)
t5['basic_stress_sensitiv'].head()
# Out:
# 0     97
# 1    108
# 2     80
# 3    104
# 4     74
# Name: basic_stress_sensitiv, dtype: int64

# %%
def basic_stress_sensitiv_indicator(bs):
    if bs > 100:
        return ('повышенная базовая чувствительность', 3) 
    elif bs >= 70:
        return ('нормальная базовая чувствительность', 2)
    else:
        return ('высокая базовая устойчивость', 1)

# %%
t5['basic_stress_sensitiv_ind'] = t5['basic_stress_sensitiv'].apply(
    lambda x: basic_stress_sensitiv_indicator(x)[0])
t5['basic_stress_sensitiv_ind'].head()
# Out:
# 0    нормальная базовая чувствительность
# 1    повышенная базовая чувствительность
# 2    нормальная базовая чувствительность
# 3    повышенная базовая чувствительность
# 4    нормальная базовая чувствительность
# Name: basic_stress_sensitiv_ind, dtype: object

# %%
t5['basic_stress_sensitiv_code'] = t5['basic_stress_sensitiv'].apply(
    lambda x: basic_stress_sensitiv_indicator(x)[1])
t5['basic_stress_sensitiv_code'].head()
# Out:
# 0    2
# 1    3
# 2    2
# 3    3
# 4    2
# Name: basic_stress_sensitiv_code, dtype: int64

# %%
basic_stress_sensitiv_res = t5['basic_stress_sensitiv_ind'].value_counts()
basic_stress_sensitiv_res
# Out:
# basic_stress_sensitiv_ind
# нормальная базовая чувствительность    35
# высокая базовая устойчивость           33
# повышенная базовая чувствительность    21
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(6,3))

wedges, texts, autotexts = ax.pie(x=basic_stress_sensitiv_res, 
                                  autopct='%1.1f%%',
                                  textprops={'fontsize':10},
                                  colors=['lightblue', 'lightgreen', 'orange'])
ax.legend(wedges, basic_stress_sensitiv_res.index,
          title='Уровень базовой реакции на стресс:',
          loc='center left',
          bbox_to_anchor=(1, 0, 0.5, 1))
plt.title('Результаты обработки методики «Тест на стрессоустойчивость» (базовая)', loc='left')
plt.savefig('t5a.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# **Вывод**. Почти $24\%$ студенток имеют повышенную базовую стрессочувствительность, $39\%$ &ndash; нормальную, $37\%$ &ndash; низкую, т.е. для них, наоборот, характерна высокая базовая устойчивость.

# %%
t3['bas_str_sens'] = t5['basic_stress_sensitiv_code']
t3['bas_str_sens'].head()
# Out:
# 0    2
# 1    3
# 2    2
# 3    3
# 4    2
# Name: bas_str_sens, dtype: int64

# %%
bas_str_sens_psm_25_me_hi = t3.groupby('bas_str_sens')['psm_25_me_hi'].value_counts(normalize=True)
bas_str_sens_psm_25_me_hi
# Out:
# bas_str_sens  psm_25_me_hi
# 1             0               0.939394
#               1               0.060606
# 2             0               0.714286
#               1               0.285714
# 3             1               0.809524
#               0               0.190476
# Name: proportion, dtype: float64

# %% [markdown]
# **Вывод**. Тест на стрессочувствительность в исследуемой группе подтвердил свою внешнюю валидность, т.к. в подгруппе девушек с базовой устойчивостью к стрессу только у $6\%$ отмечен средний/высокий уровень стресса по методике PSM-25, в подгруппе студенток с нормальной чувствительностью &ndash; $29\%$, и в подгруппе с повышенной чувствительностью &ndash; $81\%$.

# %%
bas_str_sens_stressors = t3.groupby('bas_str_sens')['max_stressor'].value_counts(normalize=True)*100
bas_str_sens_stressors
# Out:
# bas_str_sens  max_stressor
# 1             Учеба (работа) / дела            30.303030
#               Конкуренция                      24.242424
#               Финансы                          15.151515
#               Нарушение планов                  9.090909
#               Общее самочувствие                9.090909
#               Семья                             6.060606
#               Взаимоотношения с окружающими     3.030303
#               Окружающая действительность       3.030303
# 2             Учеба (работа) / дела            28.571429
#               Общее самочувствие               25.714286
#               Финансы                          14.285714
#               Взаимоотношения с окружающими     8.571429
#               Нарушение планов                  8.571429
#               Конкуренция                       5.714286
#               Планирование                      5.714286
#               Семья                             2.857143
# ...

# %% [markdown]
# **Вывод.** Независимо от типа стрессочувствительности, главным стрессором у большинства является "Учеба (работа) / дела". В подгруппе девушек с базовой устойчивостью к стрессу на 2 месте стрессор "Конкуренция", в подгруппах с нормальной и повышенной стрессочувствительностью &ndash; "Общее самочувствие".

# %%
t5['actual_stress_sensitiv'] = t5['basic_stress_sensitiv'] - t5['constr_overcom'] + t5['stress_dynam']
t5['actual_stress_sensitiv'].head()
# Out:
# 0     74
# 1     71
# 2    100
# 3    109
# 4     44
# Name: actual_stress_sensitiv, dtype: int64

# %%
def actual_stress_sensitiv_indicator(ass):
    if ass > 85:
        return ('повышенная чувствительность к стрессу', 3)
    elif ass >= 35:
        return ('норма', 2)
    else:
        return ('устойчивость к стрессу', 1)

# %%
t5['actual_stress_sensitiv_ind'] = t5['actual_stress_sensitiv'].apply(
    lambda x: actual_stress_sensitiv_indicator(x)[0])
t5['actual_stress_sensitiv_ind'].head()
# Out:
# 0                                    норма
# 1                                    норма
# 2    повышенная чувствительность к стрессу
# 3    повышенная чувствительность к стрессу
# 4                                    норма
# Name: actual_stress_sensitiv_ind, dtype: object

# %%
t5['actual_stress_sensitiv_code'] = t5['actual_stress_sensitiv'].apply(
    lambda x: actual_stress_sensitiv_indicator(x)[1])
t5['actual_stress_sensitiv_code'].head()
# Out:
# 0    2
# 1    2
# 2    3
# 3    3
# 4    2
# Name: actual_stress_sensitiv_code, dtype: int64

# %%
actual_stress_sensitiv_res = t5['actual_stress_sensitiv_ind'].value_counts()
actual_stress_sensitiv_res
# Out:
# actual_stress_sensitiv_ind
# норма                                    45
# повышенная чувствительность к стрессу    23
# устойчивость к стрессу                   21
# Name: count, dtype: int64

# %%
fig, axs = plt.subplots(1, 2, figsize=(6,3))
fig.suptitle('Результаты обработки методики «Тест на стрессоустойчивость»', 
             x=0.75, y=1.05) # ha='right')
axs[0].pie(x=basic_stress_sensitiv_res, 
           autopct='%1.1f%%',
           textprops={'fontsize':8},
           colors=['lightblue', 'lightgreen', 'orange'])
axs[0].set_title('Базовая стрессочувствительность', fontsize=8)
axs[0].legend(['норма', 'устойчивость к стрессу', 'повышенная стрессочувствительность'],
              title='Уровень реакции на стресс:',
              loc='center left',
              bbox_to_anchor=(2.3, 0.5),
              fontsize=8)
axs[1].pie(x=actual_stress_sensitiv_res, 
           autopct='%1.1f%%',
           textprops={'fontsize':8},
           colors=['lightblue', 'orange', 'lightgreen'])
axs[1].set_title('Актуальная стрессочувствительность', fontsize=8)
plt.savefig('t5c.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# **Вывод**. Почти $26\%$ студенток имеют повышенную актуальную стрессочувствительность, $51\%$ &ndash; нормальную, $24\%$ &ndash; низкую (т.е. у них высокая актуальная стрессоустойчивость).

# %%
t3['act_str_sens'] = t5['actual_stress_sensitiv_code']
t3['act_str_sens'].head()
# Out:
# 0    2
# 1    2
# 2    3
# 3    3
# 4    2
# Name: act_str_sens, dtype: int64

# %%
act_str_sens_psm_25_me_hi = t3.groupby('act_str_sens')['psm_25_me_hi'].value_counts(normalize=True)
act_str_sens_psm_25_me_hi
# Out:
# act_str_sens  psm_25_me_hi
# 1             0               1.000000
# 2             0               0.666667
#               1               0.333333
# 3             1               0.608696
#               0               0.391304
# Name: proportion, dtype: float64

# %%
act_str_sens_psm_25_me_hi[1,1] = 0.005
act_str_sens_psm_25_me_hi
# Out:
# act_str_sens  psm_25_me_hi
# 1             0               1.000000
# 2             0               0.666667
#               1               0.333333
# 3             1               0.608696
#               0               0.391304
# 1             1               0.005000
# Name: proportion, dtype: float64

# %%
width = 0.3
x = np.arange(3)
plt.subplots(figsize=(6, 3))
plt.bar(x - width/2, (bas_str_sens_psm_25_me_hi[:,1].sort_values())*100, width, color='lightblue')
plt.bar(x + width/2, (act_str_sens_psm_25_me_hi[:,1].sort_values())*100, width, color='blue')
plt.legend(title='Тип стрессочувствительности:', labels=['базовая', 'актуальная'])
plt.ylabel('Доля, %')
plt.xlabel('Уровень стрессочувствительности')
plt.xticks(x, labels=['устойч. к стрессу', 'норма', 'повыш. чувств.'])
plt.title('Доля девушек со средним/высоким уровнем стресса по PSM-25\n'+\
          'в подгруппах с разной стрессочувствительностью')
plt.savefig('t5b.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# **Вывод**. Аналогичные результаты получены и для актуальной стрессочувствительности (см. выше про базовую), при этом среди девушек с актуальной устойчивостью к стрессу вообще не оказалось ни одной со средним/высоким уровнем стресса.

# %%
act_str_sens_stressors = t3.groupby('act_str_sens')['max_stressor'].value_counts(normalize=True)*100
act_str_sens_stressors
# Out:
# act_str_sens  max_stressor
# 1             Учеба (работа) / дела            38.095238
#               Конкуренция                      19.047619
#               Общее самочувствие               14.285714
#               Нарушение планов                  9.523810
#               Финансы                           9.523810
#               Взаимоотношения с окружающими     4.761905
#               Семья                             4.761905
# 2             Учеба (работа) / дела            26.666667
#               Общее самочувствие               20.000000
#               Финансы                          15.555556
#               Взаимоотношения с окружающими     8.888889
#               Нарушение планов                  8.888889
#               Конкуренция                       6.666667
#               Планирование                      4.444444
#               Семья                             4.444444
#               Окружающая действительность       2.222222
# ...

# %% [markdown]
# **Вывод.** В подгруппах девушек-студенток с актуальной устойчивостью к стрессу и нормальной стрессочувствительностью на 1-2 месте находятся те же стрессоры, что и в соответствующих подгруппах с базовой чувствительностью. В отличие от базовой стрессочувствительности, главным стрессором у большинства девушек с повышенной актуальной чувствительностью является "Конкуренция".

# %%
act_str_sens_stressors = t3.groupby('act_str_sens')['max_stressor'].value_counts(normalize=True)*100
act_str_sens_stressors
# Out:
# act_str_sens  max_stressor
# 1             Учеба (работа) / дела            38.095238
#               Конкуренция                      19.047619
#               Общее самочувствие               14.285714
#               Нарушение планов                  9.523810
#               Финансы                           9.523810
#               Взаимоотношения с окружающими     4.761905
#               Семья                             4.761905
# 2             Учеба (работа) / дела            26.666667
#               Общее самочувствие               20.000000
#               Финансы                          15.555556
#               Взаимоотношения с окружающими     8.888889
#               Нарушение планов                  8.888889
#               Конкуренция                       6.666667
#               Планирование                      4.444444
#               Семья                             4.444444
#               Окружающая действительность       2.222222
# ...

# %% [markdown]
# **Вывод.** В подгруппах девушек-студенток с актуальной устойчивостью к стрессу и нормальной стрессочувствительностью на 1-2 месте находятся те же стрессоры, что и в соответствующих подгруппах с базовой чувствительностью. В отличие от базовой стрессочувствительности, главным стрессором у большинства девушек с повышенной актуальной чувствительностью является "Конкуренция", что может быть связано со сменом типа учебной деятельности на первых курсах медицинского вуза по сравнению со школой.

# %%
plt.figure(figsize=(6, 3)) 
plt.scatter(x=t5['basic_stress_sensitiv'], 
            y=t5['actual_stress_sensitiv'], 
            s=10, c='blue')
plt.text(40, 120, 
         f"r={spearmanr(t5['basic_stress_sensitiv'], t5['actual_stress_sensitiv'])[0]:.2f}", 
         fontsize=10)
plt.text(40, 110, 
         f"(p={spearmanr(t5['basic_stress_sensitiv'], t5['actual_stress_sensitiv'])[1]:.3f})", 
         fontsize=10)
plt.xlabel('Базовая, балл')
plt.ylabel('Актуальная, балл')
plt.suptitle('Корреляция между базовой и актуальной стрессочувствительностью')
plt.savefig('t5d.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# **Вывод.** Между базовой и актуальной стрессочувствительностью отмечается высокая корреляция, поэтому для кластерного анализа можно оставить один из показателей.

# %%
stress_scales = ['frustrat', 'perf', 'psychosom', 
                 'destr_overcom', 'constr_overcom', 'stress_dynam']
stress_scales_res = [frustrat_res, perf_res, psychosom_res, 
                     destr_overcom_res, constr_overcom_res, stress_dynam_res]
stress_scales_rus = ['Фрустрация', 'Перфекционизм', 'Психосоматика',
                     'Деструктивные способы борьбы', 'Конструктивные способы борьбы', 'Динамика уровня стресса за 3 года']

# %%
plt.figure(figsize=(12, 8)) 
for i in list(range(1,7)):
    plt.subplot(3, 2, i)
    t5[stress_scales[i-1]].hist(bins=45, alpha=0.5, label=stress_scales_rus[i-1])
    plt.xlabel('Баллы')
    plt.ylabel('Кол-во ответов')
    plt.legend()
plt.suptitle('Результаты обработки методики «Тест на стрессоустойчивость» (шкалы)')
plt.savefig('t5e.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# **Вывод**. Распределение большинства компонентов стрессочувствительности близки к нормальным или бимодальным. По шкалам фрустрации и психосоматики наблюдаются смещенные влево моды, вероятно, относящиеся к девушкам с низким уровнем стресса (т.е. с устойчивостью к стрессу).

# %%
plt.figure(figsize=(10, 10)) 
for i in list(range(1,7)):
    ax = plt.subplot(3, 2, i)
    wedges, texts, autotexts = ax.pie(x=stress_scales_res[i-1], 
                                      autopct='%1.1f%%',
                                      textprops={'fontsize':8})
    ax.legend(wedges, stress_scales_res[i-1].index,
              title='Уровень',
              loc='center left',
              bbox_to_anchor=(1, 0, 0.5, 1),
              fontsize=8)
    plt.title(stress_scales_rus[i-1], loc='center', fontsize=8)
plt.suptitle('Результаты обработки методики «Тест на стрессоустойчивость» (шкалы)', x=0.55, y=0.93)
plt.savefig('t5f.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# **Вывод**. У $21\%$ девушек отмечается высокий уровень фрустрации, у $33\%$ &ndash; перфекционизма, у $9\%$ &ndash; высокая склонность к психосоматическим заболеваниям; примерно половина девушек имеют средний уровень этих показателей, остальные &ndash; низкий.
#
# Высокую склонность к конструктивным и деструктивным копинг-стратегиям имеют, соответственно, $20\%$ и $26\%$ студенток, среднюю &ndash; $47\%$ и $66\%$ соответственно. Значит, деструктивные способы справиться со стрессом в изучаемой группе преобладают.
#
# У $67\%$ девушек уровень стресса в течение последних 3 лет увеличился, в том числе у $27\%$ &ndash; значительно.

# %%
corr_matrix_with_pval(t5[stress_scales + ['basic_stress_sensitiv', 'actual_stress_sensitiv']], 
                      method = 'spearman', 
                      figsize=(15, 5))

# %%
stress_scales_codes = ['frustrat_code', 'perf_code', 'psychosom_code', 
                       'destr_overcom_code', 'constr_overcom_code', 'stress_dynam_code', 
                       'basic_stress_sensitiv_code', 'actual_stress_sensitiv_code']

# %%
corr_matrix_with_pval(t5[stress_scales_codes], 
                      method = 'spearman', 
                      figsize=(15, 5))

# %% [markdown]
# **Вывод**. Показатель актуальной стрессочувствительность значимо или высоко коррелирует со всеми остальными показателями стрессочувствительности, за исключением уровня конструктивных способов борьбы со стрессом. Поэтому для кластерного анализа можно взять показатели `actual_stress_sensitiv` и `constr_overcom`.

# %% [markdown]
# Интерес также представляет умеренная положительная корреляция между показателями уровней конструктивных и деструктивных способов борьбы со стрессом. Рассмотрим их связь подробнее, выделив соответствующие подгруппы.

# %%
pd.DataFrame(t5.groupby('constr_overcom_code').value_counts(
    ['destr_overcom_code'], normalize=True, sort=False)*100)
# Out:
#                                         proportion
# constr_overcom_code destr_overcom_code
# 1                   1                    13.793103
#                     2                    75.862069
#                     3                    10.344828
# 2                   1                     4.761905
#                     2                    73.809524
#                     3                    21.428571
# 3                   1                     5.555556
#                     2                    33.333333
#                     3                    61.111111

# %% [markdown]
# **Вывод.** Независимо от уровня показателя конструктивных копинг-стратегий, $85-95\%$ студенток используют также деструктивные стратегии на среднем или высоком уровне, причем в подгруппе с высоким уровнем *конструктивных* стратегий доля девушек, имеющих высокий показатель *деструктивных* стратегий, составляет $61\%$.

# %%
t3['constr_overcom_code'] = t5['constr_overcom_code']
t3['constr_overcom_code'].head()
# Out:
# 0    2
# 1    3
# 2    2
# 3    3
# 4    3
# Name: constr_overcom_code, dtype: int64

# %%
t3['destr_overcom_code'] = t5['destr_overcom_code']
t3['destr_overcom_code'].head()
# Out:
# 0    2
# 1    2
# 2    2
# 3    3
# 4    2
# Name: destr_overcom_code, dtype: int64

# %%
pd.DataFrame(t3.groupby('psm_25_me_hi').value_counts(
    ['constr_overcom_code'], normalize=True, sort=False)*100)
# Out:
#                                   proportion
# psm_25_me_hi constr_overcom_code
# 0            1                     33.333333
#              2                     51.666667
#              3                     15.000000
# 1            1                     31.034483
#              2                     37.931034
#              3                     31.034483

# %%
pd.DataFrame(t3.groupby('psm_25_me_hi').value_counts(
    ['destr_overcom_code'], normalize=True, sort=False)*100)
# Out:
#                                  proportion
# psm_25_me_hi destr_overcom_code
# 0            1                    11.666667
#              2                    76.666667
#              3                    11.666667
# 1            2                    44.827586
#              3                    55.172414

# %% [markdown]
# **Вывод.** Независимо от уровня стресса (по методике *PSM-25*), доля девушек, применяющих конструктивные копинг-стратегии, составляет примерно $70\%$.
#
# Среди девушек с низким уровнем стресса низкий уровень деструктивных стратегий отмечен только у $12\%$, средний у $77\%$; среди девушек со средним/высоким уровнем стресса $45\%$ используют деструктивные стратегии на среднем уровне, остальные $55\%$ на высоком

# %%
pd.DataFrame(t3.groupby('act_str_sens').value_counts(
    ['constr_overcom_code'], normalize=True, sort=False)*100)
# Out:
#                                   proportion
# act_str_sens constr_overcom_code
# 1            1                     28.571429
#              2                     42.857143
#              3                     28.571429
# 2            1                     37.777778
#              2                     46.666667
#              3                     15.555556
# 3            1                     26.086957
#              2                     52.173913
#              3                     21.739130

# %%
pd.DataFrame(t3.groupby('act_str_sens').value_counts(
    ['destr_overcom_code'], normalize=True, sort=False)*100)
# Out:
#                                  proportion
# act_str_sens destr_overcom_code
# 1            1                    19.047619
#              2                    76.190476
#              3                     4.761905
# 2            1                     4.444444
#              2                    71.111111
#              3                    24.444444
# 3            1                     4.347826
#              2                    47.826087
#              3                    47.826087

# %% [markdown]
# **Вывод.** Доля девушек, применяющих конструктивные копинг-стратегии на среднем или высоком уровне, существенно не зависит от уровня актуальной стрессочувствительности и составляет $62-74\%$.
#
# Доля девушек, применяющих деструктивные копинг-стратегии на среднем или высоком уровне, также существенно не зависит от уровня актуальной стрессочувствительности и составляет $80-95\%$.

# %%
t5 = t5.join(t2[motiv])
t5[motiv].head(3)
# Out:
#    cogn  achiev  intro   ext
# 0  95.0   100.0   95.0  55.0
# 1  85.0    75.0   80.0  50.0
# 2  40.0    45.0   45.0  55.0

# %%
costr_str_motiv = t5.groupby('constr_overcom_code')[motiv].mean().T
costr_str_motiv
# Out:
# constr_overcom_code          1          2          3
# cogn                 80.172414  81.428571  90.555556
# achiev               71.724138  73.690476  82.222222
# intro                72.931034  72.738095  74.166667
# ext                  57.758621  57.976190  55.277778

# %%
costr_str_motiv['p-value'] = 0.0
for x in costr_str_motiv.index:
    p = htest(t5.query('constr_overcom_code==1')[x], 
              t5.query('constr_overcom_code==2')[x],
              t5.query('constr_overcom_code==3')[x]).pvalue
    costr_str_motiv.loc[x, 'p-value'] = round(p, 3)
costr_str_motiv
# Out:
# constr_overcom_code          1          2          3  p-value
# cogn                 80.172414  81.428571  90.555556    0.113
# achiev               71.724138  73.690476  82.222222    0.174
# intro                72.931034  72.738095  74.166667    0.979
# ext                  57.758621  57.976190  55.277778    0.822

# %%
destr_str_motiv = t5.groupby('destr_overcom_code')[motiv].mean().T
destr_str_motiv
# Out:
# destr_overcom_code          1          2          3
# cogn                77.142857  83.305085  83.478261
# achiev              68.571429  75.593220  74.565217
# intro               70.000000  74.237288  71.086957
# ext                 65.000000  55.762712  59.130435

# %%
destr_str_motiv['p-value'] = 0.0
for x in destr_str_motiv.index:
    p = htest(t5.query('destr_overcom_code==1')[x], 
              t5.query('destr_overcom_code==2')[x],
              t5.query('destr_overcom_code==3')[x]).pvalue
    destr_str_motiv.loc[x, 'p-value'] = round(p, 3)
destr_str_motiv
# Out:
# destr_overcom_code          1          2          3  p-value
# cogn                77.142857  83.305085  83.478261    0.476
# achiev              68.571429  75.593220  74.565217    0.566
# intro               70.000000  74.237288  71.086957    0.526
# ext                 65.000000  55.762712  59.130435    0.302

# %% [markdown]
# **Вывод.** Уровень мотивации статистически значимо не связан с показателем уровня конструктивных или деструктивных копинг-стратегий.
#
# Исследуем также связь уровня стресса по *PSM-25* с уровнями отдельных компонент стресса

# %%
t5['psm_25_me_hi'] = t4['psm_25_me_hi']
t5['psm_25_me_hi'].head(3)
# Out:
# 0    0
# 1    1
# 2    0
# Name: psm_25_me_hi, dtype: int64

# %%
psm_25_str_scal = t5.groupby('psm_25_me_hi')[stress_scales].mean().T
psm_25_str_scal
# Out:
# psm_25_me_hi            0          1
# frustrat        19.550000  25.172414
# perf            19.533333  28.275862
# psychosom       12.900000  23.034483
# destr_overcom   16.300000  23.793103
# constr_overcom  27.383333  29.241379
# stress_dynam    12.333333  23.103448

# %%
psm_25_str_scal['p-value'] = 0.0
for x in stress_scales:
    psm_25_str_scal.loc[x, 'p-value'] = round(utest(t5.query('psm_25_me_hi==0')[x], 
                                                    t5.query('psm_25_me_hi==1')[x]).pvalue, 3)
psm_25_str_scal.columns = ['низкий', 'высокий/средний', 'p-value']
psm_25_str_scal
# Out:
#                    низкий  высокий/средний  p-value
# frustrat        19.550000        25.172414    0.014
# perf            19.533333        28.275862    0.000
# psychosom       12.900000        23.034483    0.000
# destr_overcom   16.300000        23.793103    0.000
# constr_overcom  27.383333        29.241379    0.624
# stress_dynam    12.333333        23.103448    0.037

# %%
h = 0.3
y = np.arange(len(stress_scales))
plt.subplots(figsize=(4, 4))
plt.barh(y - h/2, psm_25_str_scal['низкий'], h, color='lightgreen')
plt.barh(y + h/2, psm_25_str_scal['высокий/средний'], h, color='pink')
plt.legend(title='Уровень стресса:', labels=['низкий', 'высокий/средний'], loc='lower left')
plt.xlabel('Балл')
plt.yticks(y, labels=stress_scales_rus)
for i in y:
    if psm_25_str_scal.iloc[i, 2] < 0.05:
        plt.text(x=round(psm_25_str_scal.iloc[i, 1]-5), y=i, s='*', fontsize=16)
plt.title('Средние значения баллов по шкалам стрессочувствительности \n'+\
          'в подгруппах с различным уровнем стресса,\n определенным по методике PSM-25')
plt.savefig('t5g.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# **Вывод.** В подгруппе девушек со средним/высоким уровнем стресса значения по всем шкалам (кроме уровня конструктивного преодоления стресса) статистически значимо (в среднем, в 1,5-2 раза) выше по сравнению с подгруппой, в которой уровень стресса низкий.
#
# Ниже для справки приводится распредение ранговых уровней по этим шкалам в подгруппах с разным уровнем стресса

# %%
stress_scales_ind = ['frustrat_ind', 'perf_ind', 'psychosom_ind',
                     'destr_overcom_ind', 'constr_overcom_ind', 'stress_dynam_ind']
t5['psm_25_me_hi'] = t5['psm_25_me_hi'].replace([0, 1],
                                                ['низкий', 'высокий/средний'])

# %%
for scale in stress_scales_ind:
    display(
        pd.DataFrame(t5.groupby('psm_25_me_hi').value_counts(
            [scale], normalize=True, sort=False)*100)
    )
# Out:
#                               proportion
# psm_25_me_hi    frustrat_ind
# высокий/средний высокая        34.482759
#                 низкая         13.793103
#                 средняя        51.724138
# низкий          высокая        15.000000
#                 низкая         38.333333
#                 средняя        46.666667
#                           proportion
# psm_25_me_hi    perf_ind
# высокий/средний высокий    58.620690
#                 низкий      3.448276
#                 средний    37.931034
# низкий          высокий    20.000000
#                 низкий     26.666667
#                 средний    53.333333
#                                proportion
# psm_25_me_hi    psychosom_ind
# высокий/средний высокая         24.137931
#                 низкая           6.896552
#                 средняя         68.965517
# низкий          высокая          1.666667
#                 низкая          48.333333
#                 средняя         50.000000
# ...

# %% [markdown]
# ## Анализ корреляционных связей изученных показателей
# ### Корреляции признаков

# %%
t_res=ag[ag_vars].join([t1['gender_code'],
                        t2[['cogn', 'ext']],
                        t3['av_stress'],
                        t4['psm_25_stress'],
                        t5[['actual_stress_sensitiv',
                            'constr_overcom']]])
t_res['gender_code'] = pd.Series(t_res['gender_code'].replace([3, 2, 1, 0], 
                                                              [1, 0, 0, 0]), dtype='int64')
t_res.rename(columns={'gender_code': 'fem_gender'}, inplace=True)
t_res.head()
# Out:
#    Mena  Coita  Coita_code  Pain  Partn  Kids  Auto  Habit  fem_gender   cogn  \
# 0    12     25           0     2      0     0     0      1           0   95.0
# 1    14     18           1     3      0     0     0      0           0   85.0
# 2    14     25           0     2      0     0     0      1           0   40.0
# 3    14     21           1     3      1     0     0      1           1   70.0
# 4     9     17           1     3      1     0     0      0           0  100.0
#
#     ext  av_stress  psm_25_stress  actual_stress_sensitiv  constr_overcom
# 0  55.0  34.955556             92                      74              33
# 1  50.0  33.233333            153                      71              47
# 2  55.0  42.600000             77                     100              30
# 3  70.0  24.344444            162                     109              45
# 4  75.0  22.977778             44                      44              40

# %%
corr_matrix_with_pval(t_res, method = 'spearman', figsize=(25, 10), 
                      title='Матрица корреляций социально-психологических характеристик '+\
                      'и результатов психологической диагностики', 
                      fname='trescorr.png')

# %% [markdown]
# **Вывод**. Среди социально-психологических показателей только уровень альгоменореи умеренно положительно коррелирует с уровнем внешней мотивации, уровнем стресса и актуальной стрессочувствительностью.
#
# Уровень познавательной мотивации умеренно отрицательно коррелирует с уровнями экстернальной мотивации, уровнем стресса и актуальной стрессочувствительностью, и умеренно положительно &ndash; с уровнем конструктивных копинг-стратегий. Уровень экстернальной мотивации умеренно положительно коррелирует с уровнем стресса.
#
# Уровень стресса заметно положительно коррелирует с актуальной стрессочувствительностью.

# %%
res_cont_vars = ['Mena', 'Coita', 'Pain', 'cogn', 'ext', 'av_stress', 
                 'psm_25_stress', 'actual_stress_sensitiv', 'constr_overcom']

# %%
res_cont_vars_rus = ['Менархе', 'Коитархе', 'Уровень менстр. боли', 
                     'Уров. познав. мотивации', 'Уров. экстерн. мотивации', 
                     'Ср. уров. стрессоров', 'Уров. стресса по PSM-25', 
                     'Актуальная стрессочув.', 'Уров. констр. преод.']

# %%
res_nom_vars = ['Coita_code', 'Partn', 'Kids', 'Auto', 'Habit', 'fem_gender']

# %%
res_nom_vars_rus = ['Живет половой жизнью', 'Есть партнер', 'Есть дети', 
                    'Есть авто', 'Проживает отдельно', 'Феминный тип']

# %%
t_med=ag[ag_med].join([t_res['fem_gender'],
                        t2['cogn'], t2['ext'],
                        t3['av_stress'],
                        t4['psm_25_stress'],
                        t5[['actual_stress_sensitiv',
                            'constr_overcom']]])
t_med.head()
# Out:
#    Mns_d  Cyc_d  Anam  Delay  Val  Pain  fem_gender   cogn   ext  av_stress  \
# 0      3     24     0      0    0     2           0   95.0  55.0  34.955556
# 1      4     32     1      0    1     3           0   85.0  50.0  33.233333
# 2      5     28     0      0    1     2           0   40.0  55.0  42.600000
# 3      6     19     1      1    0     3           1   70.0  70.0  24.344444
# 4      7     28     1      0    0     3           0  100.0  75.0  22.977778
#
#    psm_25_stress  actual_stress_sensitiv  constr_overcom
# 0             92                      74              33
# 1            153                      71              47
# 2             77                     100              30
# 3            162                     109              45
# 4             44                      44              40

# %%
corr_matrix_with_pval(t_med, method = 'spearman', figsize=(20, 6), 
                      title='Матрица корреляций медицинских характеристик и результатов психологических тестов', 
                      fname='tresmedcorr.png')

# %% [markdown]
# **Вывод**. Среди медико-социальных показателей только факт задержек месечных в анамнезе умеренно положительно коррелирует с уровнем конструктивных копинг-стратегий.

# %% [markdown]
# ### Анализ отдельных подгрупп

# %%
t_res['psm_25'] = t4['psm_25'].copy()
t_res['psm_25'] = t_res['psm_25'].replace(['средний', 'высокий'], 'средний/высокий')
t_res['psm_25'].value_counts()
# Out:
# psm_25
# низкий             60
# средний/высокий    29
# Name: count, dtype: int64

# %%
res_cont_vars = ['Mena', 'Coita', 'Pain', 'cogn', 'ext', 'av_stress', 
                 'psm_25_stress', 'actual_stress_sensitiv', 'constr_overcom']

# %%
res_cont_vars_rus = ['Менархе', 'Коитархе', 'Уровень менстр. боли', 
                     'Уров. познав. мотивации', 'Уров. экстерн. мотивации', 
                     'Ср. уров. стрессоров', 'Уров. стресса по PSM-25', 
                     'Актуальная стрессочув.', 'Уров. констр. преод.']

# %%
res_nom_vars = ['Coita_code', 'Partn', 'Kids', 'Auto', 'Habit', 'fem_gender']

# %%
res_nom_vars_rus = ['Живет половой жизнью', 'Есть партнер', 'Есть дети', 
                    'Есть авто', 'Проживает отдельно', 'Феминный тип']

# %%
t_stress_res = t_res.groupby('psm_25').mean().T
t_stress_res
# Out:
# psm_25                     низкий  средний/высокий
# Mena                    12.533333        13.103448
# Coita                   21.700000        20.241379
# Coita_code               0.450000         0.655172
# Pain                     1.733333         2.275862
# Partn                    0.400000         0.241379
# Kids                     0.033333         0.000000
# Auto                     0.100000         0.068966
# Habit                    0.466667         0.620690
# fem_gender               0.200000         0.241379
# cogn                    85.750000        76.896552
# ext                     54.083333        64.137931
# av_stress               24.152222        43.525670
# psm_25_stress           67.500000       124.586207
# actual_stress_sensitiv  53.233333        94.137931
# constr_overcom          27.383333        29.241379

# %%
t_lo = t_res[t_res['psm_25']=='низкий'].copy()
t_hi = t_res[t_res['psm_25']=='средний/высокий'].copy()

# %%
t_stress_res['p-value'] = 0.0
for x in t_stress_res.index:
    t_stress_res.loc[x, 'p-value'] = round(utest(t_lo[x], t_hi[x]).pvalue, 3)
t_stress_res
# Out:
# psm_25                     низкий  средний/высокий  p-value
# Mena                    12.533333        13.103448    0.107
# Coita                   21.700000        20.241379    0.063
# Coita_code               0.450000         0.655172    0.072
# Pain                     1.733333         2.275862    0.004
# Partn                    0.400000         0.241379    0.145
# Kids                     0.033333         0.000000    0.331
# Auto                     0.100000         0.068966    0.640
# Habit                    0.466667         0.620690    0.177
# fem_gender               0.200000         0.241379    0.662
# cogn                    85.750000        76.896552    0.019
# ext                     54.083333        64.137931    0.011
# av_stress               24.152222        43.525670    0.000
# psm_25_stress           67.500000       124.586207    0.000
# actual_stress_sensitiv  53.233333        94.137931    0.000
# constr_overcom          27.383333        29.241379    0.624

# %% [markdown]
# **Вывод.** Подгруппы, выделенные по уровню стресса, статистически значимо различаются по уровню, алгоменореи, мотивации, среднему уровню стрессоров и актуальной стрессочувствительности.

# %%
t_coita = t_res[t_res['Coita_code']==1].copy()
t_no_coita = t_res[t_res['Coita_code']==0].copy()

# %%
t_coita_res = t_res.groupby('Coita_code').mean(numeric_only=True).T

# %%
t_coita_res['p-value'] = 0.0
for x in t_coita_res.index:
    t_coita_res.loc[x, 'p-value'] = round(utest(t_coita[x], t_no_coita[x]).pvalue, 3)
t_coita_res
# Out:
# Coita_code                      0          1  p-value
# Mena                    12.837209  12.608696    0.804
# Coita                   25.000000  17.695652    0.000
# Pain                     1.767442   2.043478    0.121
# Partn                    0.046512   0.630435    0.000
# Kids                     0.000000   0.043478    0.174
# Auto                     0.069767   0.108696    0.529
# Habit                    0.511628   0.521739    0.928
# fem_gender               0.255814   0.173913    0.352
# cogn                    83.372093  82.391304    0.857
# ext                     54.534884  60.000000    0.163
# av_stress               26.050129  34.591787    0.024
# psm_25_stress           81.720930  90.195652    0.199
# actual_stress_sensitiv  60.720930  72.021739    0.093
# constr_overcom          25.302326  30.500000    0.017

# %% [markdown]
# **Вывод.** Подгруппы, выделенные по факту коитархе, статистически значимо различаются по наличию партнера, среднему уровню стрессоров и уровню конструктивных копинг-стратегий.

# %%
t_partn = t_res[t_res['Partn']==1].copy()
t_no_partn = t_res[t_res['Partn']==0].copy()

# %%
t_partn_res = t_res.groupby('Partn').mean(numeric_only=True).T

# %%
t_partn_res['p-value'] = 0.0
for x in t_partn_res.index:
    t_partn_res.loc[x, 'p-value'] = round(utest(t_partn[x], t_no_partn[x]).pvalue, 3)
t_partn_res
# Out:
# Partn                           0          1  p-value
# Mena                    12.913793  12.354839    0.207
# Coita                   22.827586  18.225806    0.000
# Coita_code               0.293103   0.935484    0.000
# Pain                     1.793103   2.129032    0.068
# Kids                     0.000000   0.064516    0.054
# Auto                     0.086207   0.096774    0.876
# Habit                    0.551724   0.451613    0.373
# fem_gender               0.224138   0.193548    0.743
# cogn                    82.586207  83.387097    0.665
# ext                     55.775862  60.322581    0.257
# av_stress               29.743870  31.813978    0.454
# psm_25_stress           89.017241  80.645161    0.250
# actual_stress_sensitiv  68.741379  62.483871    0.584
# constr_overcom          27.724138  28.483871    0.587

# %% [markdown]
# **Вывод.** Подгруппы, выделенные по наличию партнера, значимо различаются по коитархе и наличию детей.

# %%
t_habit = t_res[t_res['Habit']==1].copy()
t_no_habit = t_res[t_res['Habit']==0].copy()

# %%
t_habit_res = t_res.groupby('Habit').mean(numeric_only=True).T

# %%
t_habit_res['p-value'] = 0.0
for x in t_habit_res.index:
    t_habit_res.loc[x, 'p-value'] = round(utest(t_habit[x], t_no_habit[x]).pvalue, 3)
t_habit_res
# Out:
# Habit                           0          1  p-value
# Mena                    12.883721  12.565217    0.225
# Coita                   21.209302  21.239130    0.972
# Coita_code               0.511628   0.521739    0.928
# Pain                     1.906977   1.913043    1.000
# Partn                    0.395349   0.304348    0.373
# Kids                     0.023256   0.021739    0.974
# Auto                     0.116279   0.065217    0.407
# fem_gender               0.279070   0.152174    0.148
# cogn                    86.279070  79.673913    0.057
# ext                     56.744186  57.934783    0.760
# av_stress               28.898191  31.929469    0.305
# psm_25_stress           81.209302  90.673913    0.095
# actual_stress_sensitiv  66.279070  66.826087    0.706
# constr_overcom          28.000000  27.978261    0.783

# %% [markdown]
# **Вывод.** Подгруппы, выделенные по типу проживания, значимо не различаются по другим показателям.

# %%
t_pain_lo = t_res[t_res['Pain']==1].copy()
t_pain_me = t_res[t_res['Pain']==2].copy()
t_pain_hi = t_res[t_res['Pain']==3].copy()

# %%
t_pain_res = t_res.groupby('Pain').mean(numeric_only=True).T

# %%
t_pain_res['p-value'] = 0.0
for x in t_pain_res.index:
    if x in res_cont_vars:
        p = htest(t_pain_lo[x], t_pain_me[x], t_pain_hi[x]).pvalue
    else:
        p = chi2_test(np.array([[t_pain_lo.query(x+'==1')[x].count(), 
                                 t_pain_me.query(x+'==1')[x].count(),
                                 t_pain_hi.query(x+'==1')[x].count()], 
                               [t_pain_lo.query(x+'==0')[x].count(), 
                                t_pain_me.query(x+'==0')[x].count(),
                                t_pain_hi.query(x+'==0')[x].count()]])).pvalue
    t_pain_res.loc[x, 'p-value'] = round(p, 3)
t_pain_res
# Out:
# Pain                            1          2          3  p-value
# Mena                    12.657143  12.851852  12.666667    0.628
# Coita                   21.800000  21.296296  20.407407    0.310
# Coita_code               0.428571   0.518519   0.629630    0.291
# Partn                    0.228571   0.407407   0.444444    0.155
# Kids                     0.000000   0.074074   0.000000    0.095
# Auto                     0.142857   0.074074   0.037037    0.332
# Habit                    0.542857   0.444444   0.555556    0.662
# fem_gender               0.114286   0.296296   0.259259    0.175
# cogn                    84.428571  82.037037  81.666667    0.803
# ext                     51.285714  59.074074  63.518519    0.011
# av_stress               26.595238  33.044033  32.902058    0.213
# psm_25_stress           74.600000  92.592593  94.518519    0.043
# actual_stress_sensitiv  54.257143  72.481481  76.592593    0.048
# ...

# %% [markdown]
# **Вывод.** Подгруппы, выделенные по уровню альгоменореи, различаются по уровню экстернальной мотивации, уровню стресса и актуальной стрессочувствительности.

# %%
width = 0.2
x1 = np.arange(len(res_nom_vars))
x2 = np.arange(len(res_cont_vars[3:]))

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 3))
axs[0].bar(x1 - width/2, t_stress_res.loc[res_nom_vars, 'низкий']*100, width, color='lightgreen')
axs[0].bar(x1 + width/2, t_stress_res.loc[res_nom_vars, 'средний/высокий']*100, width, color='pink')
axs[0].legend(title='Уровень стресса:', labels=['низкий', 'средний/высокий'])
axs[0].set_ylabel('Частота, %')
axs[0].set_xticks(x1)
axs[0].set_xticklabels(res_nom_vars_rus, rotation=90)
axs[0].text(0, 55, '*', fontsize=16)   # * - статистически или практически значимое различие 
axs[0].text(1, 15, '*', fontsize=16)
axs[1].bar(x2 - width/2, t_stress_res.loc[res_cont_vars[3:], 'низкий'], width, color='lightgreen')
axs[1].bar(x2 + width/2, t_stress_res.loc[res_cont_vars[3:], 'средний/высокий'], width, color='pink')
axs[1].legend(title='Уровень стресса:', labels=['низкий', 'средний/высокий'])
axs[1].set_ylabel('Балл')
axs[1].set_xticks(x2)
axs[1].set_xticklabels(res_cont_vars_rus[3:], rotation=90)
axs[1].text(0, 60, '*', fontsize=16)
axs[1].text(1, 50, '*', fontsize=16)
axs[1].text(2, 30, '*', fontsize=16)
axs[1].text(3, 90, '*', fontsize=16)
axs[1].text(4, 70, '*', fontsize=16)
plt.suptitle('Социально-психологические характеристики девушек с разным уровнем стресса по PSM-25')
plt.savefig('tres1.png', bbox_inches='tight')
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 3))
axs[0].bar(x1 - width, t_pain_res.loc[res_nom_vars, 1]*100, width, color='lightgreen')
axs[0].bar(x1, t_pain_res.loc[res_nom_vars, 2]*100, width, color='orange')
axs[0].bar(x1 + width, t_pain_res.loc[res_nom_vars, 3]*100, width, color='pink')
axs[0].legend(title='Уровень боли:', labels=['слабая', 'средняя', 'сильная'])
axs[0].set_ylabel('Частота, %')
axs[0].set_xticks(x1)
axs[0].set_xticklabels(res_nom_vars_rus, rotation=90)
axs[0].text(1, 30, '*', fontsize=16)
axs[0].text(2, 5, '*', fontsize=16)
axs[0].text(5, 20, '*', fontsize=16)
axs[1].bar(x2 - width, t_pain_res.loc[res_cont_vars[3:], 1], width, color='lightgreen')
axs[1].bar(x2, t_pain_res.loc[res_cont_vars[3:], 2], width, color='orange')
axs[1].bar(x2 + width, t_pain_res.loc[res_cont_vars[3:], 3], width, color='pink')
axs[1].legend(title='Уровень боли:', labels=['слабая', 'средняя', 'сильная'])
axs[1].set_ylabel('Балл')
axs[1].set_xticks(x2)
axs[1].set_xticklabels(res_cont_vars_rus[3:], rotation=90)
axs[1].text(1, 45, '*', fontsize=16)
axs[1].text(3, 65, '*', fontsize=16)
axs[1].text(4, 50, '*', fontsize=16)
plt.suptitle('Социально-психологические характеристики девушек с разным уровнем менструальной боли')
plt.savefig('tres2.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# **Вывод**. Таким образом, с точки зрения уровня стресса и субъективного дискомфорта, вызванного альгоменореей, статистически значимые различия наблюдаются по показателям уровня познавательной и экстернальной мотивации, а также актуальной стрессочувствительности. С практической точки зрения важны также показатели феминного типа и коитархе. Указанные показатели используем для кластерного анализа.

# %% [markdown]
# ## Кластерный анализ

# %%
t_clust = t_res[['fem_gender', 'Coita_code', 'Pain', 
                 'cogn', 'ext', 'psm_25_stress', 'actual_stress_sensitiv']].copy()
t_clust.head()
# Out:
#    fem_gender  Coita_code  Pain   cogn   ext  psm_25_stress  \
# 0           0           0     2   95.0  55.0             92
# 1           0           1     3   85.0  50.0            153
# 2           0           0     2   40.0  55.0             77
# 3           1           1     3   70.0  70.0            162
# 4           0           1     3  100.0  75.0             44
#
#    actual_stress_sensitiv
# 0                      74
# 1                      71
# 2                     100
# 3                     109
# 4                      44

# %%
distortion = []
clust_num = range(1, 11)
for k in clust_num:
    model = KMeans(n_clusters=k, n_init=50, random_state=RAND)
    model.fit(t_clust)
    distortion.append(model.inertia_/k)

# %%
plt.figure(figsize=(6, 3))
plt.plot(clust_num, distortion, 'bx-')
plt.xticks(clust_num)
plt.xlabel('Число кластеров')
plt.ylabel('Cр. внутрикласт. откл.')
plt.savefig('tres3.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# **Вывод**. Целесообразно выделить 3-4 кластера, т.к. при большем их количестве среднее внутрикластерное отклонение перестает уменьшаться.

# %%
model = KMeans(n_clusters=3, n_init=50, random_state=RAND)
model.fit(t_clust)
t_clust['cluster'] = model.labels_.astype(int)
sns.pairplot(t_clust, hue='cluster', diag_kind='hist', vars=t_clust.columns[:-1])
plt.savefig('tres4.png', bbox_inches='tight')
plt.show()

# %%
t_clust['cluster'].value_counts(normalize=True)*100
# Out:
# cluster
# 2    41.573034
# 0    34.831461
# 1    23.595506
# Name: proportion, dtype: float64

# %%
t_clust['cluster'].value_counts()
# Out:
# cluster
# 2    37
# 0    31
# 1    21
# Name: count, dtype: int64

# %% [markdown]
# **Вывод.** В нулевой кластер вошли $31$ чел., в первый $21$ чел., во второй $37$ чел.

# %%
t_clust['psm_25'] = t_res['psm_25'].copy()
t_clust['psm_25'] = pd.Series(t_clust['psm_25'].replace(
    {'низкий': 0, 'средний/высокий': 1}), dtype='int64')
t_clust.head()
# Out:
#    fem_gender  Coita_code  Pain   cogn   ext  psm_25_stress  \
# 0           0           0     2   95.0  55.0             92
# 1           0           1     3   85.0  50.0            153
# 2           0           0     2   40.0  55.0             77
# 3           1           1     3   70.0  70.0            162
# 4           0           1     3  100.0  75.0             44
#
#    actual_stress_sensitiv  cluster  psm_25
# 0                      74        2       0
# 1                      71        2       1
# 2                     100        1       0
# 3                     109        1       1
# 4                      44        0       0

# %%
t_clust_res = t_clust.groupby('cluster').mean().T
t_clust_res['p-value'] = 0.0
for x in t_clust_res.index:
    if x in ['cogn', 'ext', 'psm_25_stress', 'actual_stress_sensitiv', 'Pain']:
        p = htest(t_clust.query('cluster==0')[x], 
                  t_clust.query('cluster==1')[x], 
                  t_clust.query('cluster==2')[x]).pvalue
    else:
        p = chi2_test(np.array([[t_clust.query('cluster==0').query(x+'==1')[x].count(), 
                                 t_clust.query('cluster==1').query(x+'==1')[x].count(),
                                 t_clust.query('cluster==2').query(x+'==1')[x].count()], 
                               [t_clust.query('cluster==0').query(x+'==0')[x].count(), 
                                t_clust.query('cluster==1').query(x+'==0')[x].count(),
                                t_clust.query('cluster==2').query(x+'==0')[x].count()]])).pvalue
    t_clust_res.loc[x, 'p-value'] = round(p, 3)        
t_clust_res
# Out:
# cluster                         0           1          2  p-value
# fem_gender               0.129032    0.428571   0.162162    0.021
# Coita_code               0.451613    0.666667   0.486486    0.279
# Pain                     1.612903    2.142857   2.027027    0.039
# cogn                    91.935484   68.571429  83.378378    0.000
# ext                     49.032258   60.952381  62.297297    0.003
# psm_25_stress           52.419355  116.714286  96.945946    0.000
# actual_stress_sensitiv  29.645161  117.380952  68.648649    0.000
# psm_25                   0.000000    0.714286   0.378378    0.000

# %%
t_clust_res.columns=['низкий риск', 'высокий риск', 'средний риск', 'p-value']
t_clust_res.head(3)
# Out:
#             низкий риск  высокий риск  средний риск  p-value
# fem_gender     0.129032      0.428571      0.162162    0.021
# Coita_code     0.451613      0.666667      0.486486    0.279
# Pain           1.612903      2.142857      2.027027    0.039

# %% [markdown]
# **Вывод.** Выделенные кластеры статистически значимо различаются по всем показателям, кроме коитархе.
#
# Таким образом, по степени воздействия стресса на девушек-студенток выделено три статистически значимо различающиеся группы риска:
# 1)	**группа низкого риска** (кластер №0, *31* чел.) – все девушки характеризуется низким уровнем стресса по *PSM-25*, имеют очень низкую актуальную стрессочувствительность, самый высокий уровень познавательной мотивации (и самый низкий – внешней мотивации), в этой группе самая низкая доля девушек феминного типа, самый низкий уровень альгоменореи.
# 2)	**группа среднего риска** (кластер №2, *37* чел.) – большинство девушек имеют низкий уровень стресса по *PSM-25*, среднюю (нормальную) актуальную стрессочувствительность, средние уровни познавательной мотивации и внешней мотивации, в этой группе также довольно низкая доля девушек феминного типа и средний уровень альгоменореи.
# 3)	**группа высокого риска** (кластер №1, *21* чел.) – подавляющее большинство девушек этой группы характеризуется средним/высоким уровнем стресса по *PSM-25*, имеют весьма высокую актуальную стрессочувствительность, живут половой жизнью, имеют самый низкий уровень познавательной мотивации (и средний – внешней мотивации), в этой группе самая высокая доля девушек феминного типа, средний уровень альгоменореи.

# %%
t_clust['cluster'] = t_clust['cluster'].replace({0: 'низкий риск', 1: 'высокий риск', 2: 'средний риск'})

# %%
t_clust.head(3)
# Out:
#    fem_gender  Coita_code  Pain  cogn   ext  psm_25_stress  \
# 0           0           0     2  95.0  55.0             92
# 1           0           1     3  85.0  50.0            153
# 2           0           0     2  40.0  55.0             77
#
#    actual_stress_sensitiv       cluster  psm_25
# 0                      74  средний риск       0
# 1                      71  средний риск       1
# 2                     100  высокий риск       0

# %% [markdown]
# Исследум, как распределились по группам риска значения отдельных показателей

# %%
gender_per_clust = pd.DataFrame(t_clust.groupby('fem_gender').value_counts(
    ['cluster'], normalize=True, sort=False)*100)
gender_per_clust
# Out:
#                          proportion
# fem_gender cluster
# 0          высокий риск   17.142857
#            низкий риск    38.571429
#            средний риск   44.285714
# 1          высокий риск   47.368421
#            низкий риск    21.052632
#            средний риск   31.578947

# %% [markdown]
# **Вывод.** Почти половина девушек с феминным типом вошли в группу высокого риска, почти треть имеют средний риск, остальные низкий

# %%
Coita_per_clust = pd.DataFrame(t_clust.groupby('Coita_code').value_counts(
    ['cluster'], normalize=True, sort=False)*100)
Coita_per_clust
# Out:
#                          proportion
# Coita_code cluster
# 0          высокий риск   16.279070
#            низкий риск    39.534884
#            средний риск   44.186047
# 1          высокий риск   30.434783
#            низкий риск    30.434783
#            средний риск   39.130435

# %% [markdown]
# **Вывод.** По $30\%$ девушек, живущих половой жизнью имеют низкий или высокий риск, остальные $40\%$ средний

# %%
Pain_per_clust = pd.DataFrame(t_clust.groupby('Pain').value_counts(
    ['cluster'], normalize=True, sort=False)*100)
Pain_per_clust
# Out:
#                    proportion
# Pain cluster
# 1    высокий риск   14.285714
#      низкий риск    51.428571
#      средний риск   34.285714
# 2    высокий риск   29.629630
#      низкий риск    25.925926
#      средний риск   44.444444
# 3    высокий риск   29.629630
#      низкий риск    22.222222
#      средний риск   48.148148

# %% [markdown]
# **Вывод.** Больше половины девушек со слабой альгоменореей имеют низкий риск, и почти половина с сильной альгоменореей – высокий. Чуть менее половины студенток со средним уровнем боли также вошлии в соответствующую группу со средним риском

# %%
psm_25_per_clust = pd.DataFrame(t_clust.groupby('psm_25').value_counts(
    ['cluster'], normalize=True, sort=False)*100)
psm_25_per_clust
# Out:
#                      proportion
# psm_25 cluster
# 0      высокий риск   10.000000
#        низкий риск    51.666667
#        средний риск   38.333333
# 1      высокий риск   51.724138
#        средний риск   48.275862

# %% [markdown]
# **Вывод.** Девушки со средним/высоким уровнем стресса примерно поровну распределились в группы среднего и высокого риска. Больше половины девушек с низким уровнем стресса вошли в группу низкого риска и только десятая часть студенток с низким уровнем стресса имеют высокий риск благодаря другим показателям

# %%
# справочная информация - наибльшие и наименьшие значения показателей в группах риска
min_max_clust_vars = t_clust[['cluster', 'cogn', 'ext', 'psm_25_stress', 
                              'actual_stress_sensitiv']].groupby('cluster').agg(['min', 'max'])
min_max_clust_vars
# Out:
#               cogn          ext        psm_25_stress       \
#                min    max   min    max           min  max
# cluster
# высокий риск  40.0  100.0  35.0   85.0            67  162
# низкий риск   70.0  100.0  20.0   85.0            27   94
# средний риск  50.0  100.0  20.0  100.0            67  153
#
#              actual_stress_sensitiv
#                                 min  max
# cluster
# высокий риск                     85  173
# низкий риск                      -4   65
# средний риск                     39  104

# %%
# запись полученных выше таблиц в эксель-файл "t_res.xlsx"
with pd.ExcelWriter('t_res.xlsx') as writer:  
    ag_res.to_excel(writer, sheet_name='ag_res')
    ag_med_res.to_excel(writer, sheet_name='ag_med_res')
    psm_25_str_scal.to_excel(writer, sheet_name='psm_25_str_scal')
    t_stress_res.to_excel(writer, sheet_name='t_stress_res')
    t_pain_res.to_excel(writer, sheet_name='t_pain_res')
    t_clust_res.to_excel(writer, sheet_name='t_clust_res')
    Pain_per_clust.to_excel(writer, sheet_name='Pain_per_clust')
    gender_per_clust.to_excel(writer, sheet_name='gender_per_clust')
    Coita_per_clust.to_excel(writer, sheet_name='Coita_per_clust')
    psm_25_per_clust.to_excel(writer, sheet_name='psm_25_per_clust')
    min_max_clust_vars.to_excel(writer, sheet_name='min_max_clust_vars')

# %% [markdown]
# ## Общий вывод
# Исследование позволило выявить **значимые черты психологического профиля студенток**. У пятой части девушек установлен феминный гендерный тип, у большинства он андрогинный. Раздельно проживают от родителей половина студенток, более трети имеют постоянного партнера, средний возраст начала половой жизни (у начавших ее) составляет 18 лет; 40% девушек субъективно оценивают привычный уровень менструальной боли как слабый, средний и сильный – по 30%.
#
# Средний **уровень мотивации** достижения составил 75%, познавательной мотивации – 83%, причем эти типы мотивации сильно коррелирует между собой, что может свидетельствовать о конкурентно-иерархическом отношении к учебе. Средний уровень интроецированной  мотивации составил 73%, экстернальной мотивации – 57%. Личный и средний ранги мотивации достижения и интроецированной мотивации различаются, что может означать неосознанное вытеснение преобладающего типа своей мотивации.
#
# Средний или высокий **уровень стресса (по *PSM-25*)** отмечен у каждой третьей девушки, при этом средний уровень стрессоров по методике «Опросник повседневных стрессоров» относительно невелик и составляет 31%. Почти у трети студенток главным стрессором является «Учеба (работа) / дела», следующий по популярности стрессор – «Общее самочувствие», некоторые девушки прежде всего выделяют стрессоры «Конкуренция» и «Финансы». Менее, чем у 10% студенток на первом месте стрессоры, связанные с личными или семейными отношениями, что подтверждает преобладающую роль учебной деятельности и соответствующих переживаний. При этом сила переживаемого стресса не связана с преобладанием конкретного стрессора.
#
# У 67% девушек уровень стресса в течение последних 3 лет увеличился, в том числе у 27% – значительно.  Более четверти студенток имеют повышенную актуальную стрессочувствительность, более половины – нормальную, и 24% стрессоустойчивы.
#
# **Показателями,** умеренно или значимо **коррелирующими** с уровнем стресса являются:
# - актуальная стрессочувствительность;
# - уровни познавательной и экстернальной мотивации;
# - средний уровень стрессоров;
# - уровень привычной менструальной боли.
#
# При этом в подгруппах с низким и высоким/средним уровнем стресса довольно высок как уровень познавательной мотивации (86 и 77% соответственно), так и экстернальной (54 и 64%).
#
# У пятой части девушек отмечается высокий уровень **фрустрации**, у трети – **перфекционизма**, у каждой десятой – высокая склонность к **психосоматическим заболеваниям**; примерно половина девушек имеют средний уровень этих показателей. У девушек со средним/высоким уровнем стресса по *PSM-25* в 2 раза чаще встречаются **женские болезни** по сравнению с девушками, у которых уровень стресса низкий.
#
# Девушки независимо от уровня стресса проявляют одинаково высокую склонность к **конструктивным и деструктивным копинг-стратегиям,** так, даже в подгруппе с высоким уровнем конструктивных стратегий более 60% студенток имеют высокий уровень деструктивных стратегий.
#
# Таким образом, у студенток 2 курса медицинского вуза **имеются значительные ресурсы** и условия для преодоления стресса и управления им:
# - высокий уровень познавательной мотивации;
# - низкий уровень стресса у большинства студенток;
# - наличие определенных копинг-стратегий.
#
# Однако **настороженность** вызывает:
# - одинаковая приверженность девушек как конструктивным, так и деструктивным стратегиям (в том числе аддиктивным);
# - повышенная чувствительность к стрессу у каждой четвертой студентки (что довольно много, учитывая специфику будущей профессии);
# - довольно высокий уровень экстернальной (т.е. внешней, принуждающей) мотивации у всех девушек.
#
# Учитывая вышеуказанные особенности, мы смогли выделить **три группы риска,** раздельная работа с которыми позволит **оптимизировать** оказание психологической помощи:
# 1)	*группа низкого риска* (*31* чел.) – все девушки характеризуется низким уровнем стресса по *PSM-25*, имеют очень низкую актуальную стрессочувствительность, самый высокий уровень познавательной мотивации (и самый низкий – внешней мотивации), в этой группе самая низкая доля девушек феминного типа, самый низкий уровень альгоменореи.
# 2)	*группа среднего риска* (*37* чел.) – большинство девушек имеют низкий уровень стресса по *PSM-25*, среднюю (нормальную) актуальную стрессочувствительность, средние уровни познавательной мотивации и внешней мотивации, в этой группе также довольно низкая доля девушек феминного типа и средний уровень альгоменореи.
# 3)	*группа высокого риска* (*21* чел.) – подавляющее большинство девушек этой группы характеризуется средним/высоким уровнем стресса по *PSM-25*, имеют весьма высокую актуальную стрессочувствительность, живут половой жизнью, имеют самый низкий уровень познавательной мотивации (и средний – внешней мотивации), в этой группе самая высокая доля девушек феминного типа, средний уровень альгоменореи.
